# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import random
from datetime import datetime
import seaborn as sns

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Loading Data

# %%
data_path = r"C:/Users/divyas/Documents/hackathons/CMI_PB/Tasks/Task_IGg_PT/Data_Task_IGg_PT/"

X_train = pd.read_csv(data_path + "abtiter_data_X_train.csv", index_col=0)
y_train = pd.read_csv(data_path + "abtiter_data_y_train.csv", index_col=0)
X_test = pd.read_csv(data_path + "abtiter_data_X_test.csv", index_col=0)

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
# Out:
# X_train shape: (111, 42)
# y_train shape: (111, 1)
# X_test shape: (54, 42)

# %%
X_train.head()
# Out:
#              IgG_PRN    IgG_FHA   IgG1_PT  IgG1_PRN  IgG1_FHA  IgG1_FIM2/3  \
# subject_id
# 1           2.602350  34.050956  7.334714  2.174783  3.013252     1.188744
# 3           7.652635   1.096457  1.424098  3.161591  1.287515     0.322658
# 4           5.670403   1.048276  3.888604  2.591155  1.269821     2.621216
# 5           5.268274   0.084437  7.456313  2.760065  2.864834     7.487345
# 6           0.090176   0.379290  0.084132  0.025479  0.654192     0.681225
#
#              IgG1_TT   IgG1_DT   IgG1_OVA   IgG2_PT  ...  specimen_type  \
# subject_id                                           ...
# 1           1.428852  2.389153   0.665203  1.000000  ...          Blood
# 3           1.377390  1.523941  33.771912  1.000000  ...          Blood
# 4           1.675259  2.022924   5.777047  4.269877  ...          Blood
# 5           1.537432  2.250237   4.130732  6.070427  ...          Blood
# 6           0.874920  0.369367  10.452881  1.000000  ...          Blood
#
#             visit  infancy_vac  biological_sex               ethnicity   race  \
# subject_id
# 1               1           wP          Female  Not Hispanic or Latino  White
# 3               1           wP          Female                 Unknown  White
# 4               1           wP            Male  Not Hispanic or Latino  Asian
# 5               1           wP            Male  Not Hispanic or Latino  Asian
# 6               1           wP          Female  Not Hispanic or Latino  White
#
#             year_of_birth  date_of_boost       dataset  timepoint
# subject_id
# 1              1986-01-01     2016-09-12  2020_dataset          0
# 3              1983-01-01     2016-10-10  2020_dataset          0
# 4              1988-01-01     2016-08-29  2020_dataset          0
# 5              1991-01-01     2016-08-29  2020_dataset          0
# 6              1988-01-01     2016-10-10  2020_dataset          0
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Convert 'date_of_boost' and 'year_of_birth' to datetime format for both training and test sets
X_train['date_of_boost'] = pd.to_datetime(X_train['date_of_boost'], errors='coerce')
X_test['date_of_boost'] = pd.to_datetime(X_test['date_of_boost'], errors='coerce')
X_train['year_of_birth'] = pd.to_datetime(X_train['year_of_birth'], format='%Y-%m-%d', errors='coerce')
X_test['year_of_birth'] = pd.to_datetime(X_test['year_of_birth'], format='%Y-%m-%d', errors='coerce')

# Function to calculate 'age' based on 'year_of_birth' and 'date_of_boost'
def calculate_age(row):
    if pd.notnull(row['year_of_birth']) and pd.notnull(row['date_of_boost']):
        return row['date_of_boost'].year - row['year_of_birth'].year
    return None  # Handle missing values gracefully

# Calculate 'age' for training and test datasets
X_train['age'] = X_train.apply(calculate_age, axis=1)
X_test['age'] = X_test.apply(calculate_age, axis=1)


# Map categorical columns and drop unnecessary columns
X_train['infancy_vac'] = X_train['infancy_vac'].map({'wP': 0, 'aP': 1})
X_train['biological_sex'] = X_train['biological_sex'].map({'Female': 0, 'Male': 1})
X_test['infancy_vac'] = X_test['infancy_vac'].map({'wP': 0, 'aP': 1})
X_test['biological_sex'] = X_test['biological_sex'].map({'Female': 0, 'Male': 1})

# Combine X_train and X_test for consistent encoding. We do this because some races in train are not available in test.
X_combined = pd.concat([X_train, X_test], axis=0)

# Perform one-hot encoding on 'race' across the entire dataset
X_combined = pd.get_dummies(X_combined, columns=['race'], drop_first=False)

# Separate back into training and test sets based on their original indices
X_train_new = X_combined.loc[X_train.index]
X_test_new = X_combined.loc[X_test.index]

# Drop metadata columns not required for training and testing
metadata_columns = ['dataset', 'timepoint', 'date_of_boost', 'year_of_birth', 'ethnicity', 'visit', 'specimen_type']
X_train_new = X_train_new.drop(columns=metadata_columns, errors='ignore')
X_test_new = X_test_new.drop(columns=metadata_columns, errors='ignore')

# Print processed data for verification
print("X_train after processing:", X_train_new.head())
print("X_test after processing:", X_test_new.head())


# Standardize the dataset (fit only on training data)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_new)
X_test_scaled = scaler.transform(X_test_new)

# # Convert to tensor format
# X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
# X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
# y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32)
# Out:
# X_train after processing:              IgG_PRN    IgG_FHA   IgG1_PT  IgG1_PRN  IgG1_FHA  IgG1_FIM2/3  \
# subject_id
# 1           2.602350  34.050956  7.334714  2.174783  3.013252     1.188744
# 3           7.652635   1.096457  1.424098  3.161591  1.287515     0.322658
# 4           5.670403   1.048276  3.888604  2.591155  1.269821     2.621216
# 5           5.268274   0.084437  7.456313  2.760065  2.864834     7.487345
# 6           0.090176   0.379290  0.084132  0.025479  0.654192     0.681225
#
#              IgG1_TT   IgG1_DT   IgG1_OVA   IgG2_PT  ...  infancy_vac  \
# subject_id                                           ...
# 1           1.428852  2.389153   0.665203  1.000000  ...            0
# 3           1.377390  1.523941  33.771912  1.000000  ...            0
# 4           1.675259  2.022924   5.777047  4.269877  ...            0
# 5           1.537432  2.250237   4.130732  6.070427  ...            0
# 6           0.874920  0.369367  10.452881  1.000000  ...            0
#
#             biological_sex  age  race_American Indian/Alaska Native  \
# subject_id
# 1                        0   30                               False
# 3                        0   33                               False
# 4                        1   28                               False
# 5                        1   25                               False
# 6                        0   28                               False
#
#             race_Asian  race_Black or African American  \
# subject_id
# 1                False                           False
# 3                False                           False
# 4                 True                           False
# 5                 True                           False
# 6                False                           False
#
#             race_More Than One Race  \
# subject_id
# 1                             False
# 3                             False
# 4                             False
# 5                             False
# 6                             False
#
#             race_Native Hawaiian or Other Pacific Islander  \
# subject_id
# 1                                                    False
# 3                                                    False
# 4                                                    False
# 5                                                    False
# 6                                                    False
#
#             race_Unknown or Not Reported  race_White
# subject_id
# 1                                  False        True
# 3                                  False        True
# 4                                  False       False
# 5                                  False       False
# 6                                  False        True
#
# [5 rows x 42 columns]
# X_test after processing:              IgG_PRN   IgG_FHA    IgG1_PT  IgG1_PRN  IgG1_FHA  IgG1_FIM2/3  \
# subject_id
# 142         0.066482  0.102288   0.452381  1.343446  0.637104     1.250859
# 146         3.039959  2.687800  27.488095  3.248061  2.481587     0.508973
# 163         0.052871  0.002726   0.510791  0.025011  0.010421     0.008366
# 124         1.053969  0.299007   1.416667  0.911267  0.298782     0.068729
# 134         1.344032  0.987074   0.904762  1.208517  1.225409     1.037801
#
#              IgG1_TT   IgG1_DT  IgG1_OVA   IgG2_PT  ...  infancy_vac  \
# subject_id                                          ...
# 142         0.137712  0.252301  0.215054  0.419355  ...            1
# 146         0.056218  0.830831  0.309677  0.709677  ...            0
# 163         0.291480  0.334586  0.395062  0.666667  ...            0
# 124         0.525460  1.147328  0.572043  0.870968  ...            1
# 134         2.272647  1.163639  1.668817  1.032258  ...            0
#
#             biological_sex  age  race_American Indian/Alaska Native  \
# subject_id
# 142                      0   31                               False
# 146                      1   31                               False
# 163                      0   30                               False
# 124                      1   22                               False
# 134                      1   32                               False
#
#             race_Asian  race_Black or African American  \
# subject_id
# 142               True                           False
# 146              False                            True
# 163              False                           False
# 124              False                           False
# 134              False                           False
#
#             race_More Than One Race  \
# subject_id
# 142                           False
# 146                           False
# 163                           False
# 124                           False
# 134                            True
#
#             race_Native Hawaiian or Other Pacific Islander  \
# subject_id
# 142                                                  False
# 146                                                  False
# 163                                                  False
# 124                                                  False
# 134                                                  False
#
#             race_Unknown or Not Reported  race_White
# subject_id
# 142                                False       False
# 146                                False       False
# 163                                False        True
# 124                                 True       False
# 134                                False       False
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Seeing Age Distribution

# %%
# # import matplotlib.pyplot as plt

# # Plot age distribution for both training and test sets
# plt.figure(figsize=(12, 6))
# plt.hist(X_train['age'], bins=20, alpha=0.6, label="Training Set", color="skyblue")
# plt.hist(X_test['age'], bins=20, alpha=0.6, label="Test Set", color="salmon")
# plt.xlabel("Age")
# plt.ylabel("Frequency")
# plt.title("Age Distribution in Training and Test Sets")
# plt.legend()
# plt.show()

# %%
# # Calculating the minimum and maximum ages in the train dataset to define appropriate age bins
# min_age_train = X_train['age'].min()
# max_age_train = X_train['age'].max()
# min_age_train, max_age_train

# %%
# # Calculating the minimum and maximum ages in the dataset to define appropriate age bins
# min_age_test = X_test['age'].min()
# max_age_test = X_test['age'].max()
# min_age_train, max_age_train

# %%
# # Define age bins (you can adjust the bins based on your data distribution)
# age_bins = [0, 20, 30, 40, 50]
# age_labels = ['0-20', '21-30', '31-40', '41-50']

# # Temporarily add an 'age_group' column to X_train for visualization purposes
# temp_X_train = X_train_new.copy()
# temp_X_train['age_group'] = pd.cut(temp_X_train['age'], bins=age_bins, labels=age_labels)

# # Combine `temp_X_train` with `y_train` for visualization without modifying original data
# data_for_plot = temp_X_train.join(y_train)

# # Box plot of immune response (IgG_PT) across different age groups
# plt.figure(figsize=(12, 6))
# sns.boxplot(x='age_group', y='IgG_PT', data=data_for_plot, palette="coolwarm")
# plt.xlabel("Age Group")
# plt.ylabel("Immune Response (IgG_PT)")
# plt.title("Immune Response Distribution Across Age Groups")

# # Save the plot as an image file
# plt.savefig("C:/Users/divyas/Documents/hackathons/CMI_PB/Tasks/Task_IGg_PT/Results/immune_response_age_groups.png", dpi=300, bbox_inches='tight')  # Change the file path as needed
# plt.show()

# # Calculate and display the correlation between age and immune response
# age_immune_corr = data_for_plot[['age', 'IgG_PT']].corr().iloc[0, 1]
# print(f"Correlation between Age and Immune Response (IgG_PT): {age_immune_corr:.4f}")

# %%
# # Compute correlation matrix
# correlation_matrix = X_train_new.join(y_train).corr()

# # Focus on correlations with the immune response variable (y_train)
# response_corr = correlation_matrix['IgG_PT'].sort_values(ascending=False)

# # Plot correlations with features on the y-axis
# plt.figure(figsize=(8, 12))
# sns.barplot(x=response_corr.values, y=response_corr.index, palette="viridis")
# plt.xlabel("Correlation with Immune Response (IgG_PT)")
# plt.ylabel("Features")
# plt.title("Feature Correlation with Immune Response (IgG_PT)")
# plt.show()

# %%
# Set a fixed seed for reproducibility
seed = 42

# Python's built-in random module
random.seed(seed)

# NumPy random generator
np.random.seed(seed)

# PyTorch random generator for CPU
torch.manual_seed(seed)

# PyTorch random generator for GPU (if using CUDA)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# Ensures deterministic behavior for certain CUDA operations (optional)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Defining Sparse Autoencoder Model

# %%
class SparseAutoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, sparsity_weight=10): ###sparsity_weight= hyperparameter
        super(SparseAutoencoder, self).__init__()
        self.encoder = nn.Linear(input_dim, hidden_dim)
        self.decoder = nn.Linear(hidden_dim, input_dim)
        self.sparsity_weight = sparsity_weight

    def forward(self, x):
        encoded = F.relu(self.encoder(x))
        decoded = self.decoder(encoded)
        return decoded, encoded

    def sparsity_loss(self, encoded):
        return self.sparsity_weight * torch.mean(torch.abs(encoded))

# %% [markdown]
# ## Split training data into train and validation sets

# %%
# Split your data
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train_scaled, y_train, test_size=0.1, random_state=42
)

# X_train_split.shape
# X_val_split.shape
# y_train_split.type()
# y_val_split.shape

# Convert the split data into tensors
X_train_tensor = torch.tensor(X_train_split, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val_split, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_split.to_numpy(), dtype=torch.float32)
y_val_tensor = torch.tensor(y_val_split.to_numpy(), dtype=torch.float32)

# Set up DataLoaders
batch_size = 32
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
x=next(iter(train_loader))
# print(x[1].shape)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
X_train_tensor.shape[1]
# Out:
# 42

# %% [markdown]
# ### Training sparse Autoencoder

# %%
# input_dim = X_train_scaled.shape[1]
# hidden_dim = 128 #hyperparameter
# sparsity_weight=10
# lr=1e-4
# model = SparseAutoencoder(input_dim=input_dim, hidden_dim=hidden_dim,sparsity_weight=sparsity_weight)
# optimizer = optim.Adam(model.parameters(), lr=lr)
# # lr=hyperparameter
# num_epochs = 500 

# train_losses = []
# val_losses=[]
# for epoch in range(num_epochs):
#     epoch_loss = 0.0
#     rec_loss=0.0
#     model.train()
#     for batch_data, _ in train_loader:
#         optimizer.zero_grad()
#         reconstructed, encoded = model(batch_data)
#         reconstruction_loss = F.mse_loss(reconstructed, batch_data)
        
#         sparsity_loss = model.sparsity_loss(encoded)
#         total_loss = reconstruction_loss + sparsity_loss
#         total_loss.backward()
#         optimizer.step()
#         epoch_loss += total_loss.item()
#         rec_loss+=reconstruction_loss
    
#     avg_epoch_loss = epoch_loss / len(train_loader.dataset)
    
#     avg_rec_loss=rec_loss/len(train_loader.dataset)
#     train_losses.append(avg_epoch_loss)
#     print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_epoch_loss:.4f}")
#     print(f"Epoch [{epoch+1}/{num_epochs}], Reconstruction Loss: {avg_rec_loss:.4f}")
#     model.eval()
    
#     with torch.no_grad():
        
#         batch_loss=0.0
#         rec_loss=0.0
#         for batch_data, _ in val_loader:
            
#             reconstructed, encoded = model(batch_data)
#             reconstruction_loss = F.mse_loss(reconstructed, batch_data)
        
#             sparsity_loss = model.sparsity_loss(encoded)
#             total_loss = reconstruction_loss + sparsity_loss
#             batch_loss += total_loss.item()
#             rec_loss+=reconstruction_loss
#         avg_batch_loss = batch_loss / len(val_loader.dataset)
#         avg_rec_loss=rec_loss/len(val_loader.dataset)
#         val_losses.append(avg_batch_loss)
#     print(f"Val Loss: {avg_batch_loss:.4f}")
#     print(f"Val Reconstruction Loss: {avg_rec_loss:.4f}")
# Out:
# Epoch [1/500], Loss: 0.1277
# Epoch [1/500], Reconstruction Loss: 0.0404
# Val Loss: 0.2054
# Val Reconstruction Loss: 0.0588
# Epoch [2/500], Loss: 0.1296
# Epoch [2/500], Reconstruction Loss: 0.0408
# Val Loss: 0.2047
# Val Reconstruction Loss: 0.0586
# Epoch [3/500], Loss: 0.1347
# Epoch [3/500], Reconstruction Loss: 0.0448
# Val Loss: 0.2041
# Val Reconstruction Loss: 0.0584
# Epoch [4/500], Loss: 0.1584
# Epoch [4/500], Reconstruction Loss: 0.0559
# Val Loss: 0.2035
# Val Reconstruction Loss: 0.0583
# Epoch [5/500], Loss: 0.1257
# Epoch [5/500], Reconstruction Loss: 0.0400
# Val Loss: 0.2030
# Val Reconstruction Loss: 0.0582
# Epoch [6/500], Loss: 0.1286
# Epoch [6/500], Reconstruction Loss: 0.0416
# Val Loss: 0.2025
# Val Reconstruction Loss: 0.0580
# Epoch [7/500], Loss: 0.1413
# Epoch [7/500], Reconstruction Loss: 0.0492
# Val Loss: 0.2020
# Val Reconstruction Loss: 0.0579
# Epoch [8/500], Loss: 0.1334
# Epoch [8/500], Reconstruction Loss: 0.0435
# Val Loss: 0.2014
# Val Reconstruction Loss: 0.0578
# Epoch [9/500], Loss: 0.1298
# Epoch [9/500], Reconstruction Loss: 0.0407
# Val Loss: 0.2009
# Val Reconstruction Loss: 0.0577
# Epoch [10/500], Loss: 0.1269
# Epoch [10/500], Reconstruction Loss: 0.0417
# Val Loss: 0.2004
# Val Reconstruction Loss: 0.0575
# Epoch [11/500], Loss: 0.1142
# Epoch [11/500], Reconstruction Loss: 0.0353
# Val Loss: 0.2000
# Val Reconstruction Loss: 0.0574
# Epoch [12/500], Loss: 0.1280
# Epoch [12/500], Reconstruction Loss: 0.0408
# Val Loss: 0.1995
# Val Reconstruction Loss: 0.0573
# Epoch [13/500], Loss: 0.1223
# Epoch [13/500], Reconstruction Loss: 0.0379
# Val Loss: 0.1989
# Val Reconstruction Loss: 0.0572
# Epoch [14/500], Loss: 0.1220
# Epoch [14/500], Reconstruction Loss: 0.0402
# Val Loss: 0.1984
# Val Reconstruction Loss: 0.0571
# Epoch [15/500], Loss: 0.1317
# Epoch [15/500], Reconstruction Loss: 0.0456
# Val Loss: 0.1979
# Val Reconstruction Loss: 0.0570
# Epoch [16/500], Loss: 0.1114
# Epoch [16/500], Reconstruction Loss: 0.0351
# Val Loss: 0.1974
# Val Reconstruction Loss: 0.0569
# Epoch [17/500], Loss: 0.1353
# Epoch [17/500], Reconstruction Loss: 0.0458
# Val Loss: 0.1969
# Val Reconstruction Loss: 0.0568
# Epoch [18/500], Loss: 0.1139
# Epoch [18/500], Reconstruction Loss: 0.0346
# Val Loss: 0.1964
# Val Reconstruction Loss: 0.0567
# Epoch [19/500], Loss: 0.1337
# Epoch [19/500], Reconstruction Loss: 0.0436
# Val Loss: 0.1959
# Val Reconstruction Loss: 0.0566
# Epoch [20/500], Loss: 0.1164
# Epoch [20/500], Reconstruction Loss: 0.0377
# Val Loss: 0.1955
# Val Reconstruction Loss: 0.0565
# Epoch [21/500], Loss: 0.1141
# Epoch [21/500], Reconstruction Loss: 0.0354
# Val Loss: 0.1950
# Val Reconstruction Loss: 0.0564
# Epoch [22/500], Loss: 0.1132
# Epoch [22/500], Reconstruction Loss: 0.0356
# Val Loss: 0.1945
# Val Reconstruction Loss: 0.0563
# Epoch [23/500], Loss: 0.1104
# Epoch [23/500], Reconstruction Loss: 0.0345
# Val Loss: 0.1940
# Val Reconstruction Loss: 0.0562
# Epoch [24/500], Loss: 0.1401
# Epoch [24/500], Reconstruction Loss: 0.0514
# Val Loss: 0.1936
# Val Reconstruction Loss: 0.0561
# Epoch [25/500], Loss: 0.1384
# Epoch [25/500], Reconstruction Loss: 0.0480
# Val Loss: 0.1931
# Val Reconstruction Loss: 0.0560
# Epoch [26/500], Loss: 0.1120
# Epoch [26/500], Reconstruction Loss: 0.0356
# Val Loss: 0.1927
# Val Reconstruction Loss: 0.0560
# Epoch [27/500], Loss: 0.1201
# Epoch [27/500], Reconstruction Loss: 0.0386
# Val Loss: 0.1923
# Val Reconstruction Loss: 0.0559
# Epoch [28/500], Loss: 0.1222
# Epoch [28/500], Reconstruction Loss: 0.0394
# Val Loss: 0.1919
# Val Reconstruction Loss: 0.0558
# Epoch [29/500], Loss: 0.1286
# Epoch [29/500], Reconstruction Loss: 0.0427
# Val Loss: 0.1915
# Val Reconstruction Loss: 0.0557
# Epoch [30/500], Loss: 0.1357
# Epoch [30/500], Reconstruction Loss: 0.0503
# Val Loss: 0.1911
# Val Reconstruction Loss: 0.0557
# Epoch [31/500], Loss: 0.1183
# Epoch [31/500], Reconstruction Loss: 0.0394
# Val Loss: 0.1907
# Val Reconstruction Loss: 0.0556
# Epoch [32/500], Loss: 0.1135
# Epoch [32/500], Reconstruction Loss: 0.0369
# Val Loss: 0.1902
# Val Reconstruction Loss: 0.0555
# Epoch [33/500], Loss: 0.1130
# Epoch [33/500], Reconstruction Loss: 0.0352
# Val Loss: 0.1897
# Val Reconstruction Loss: 0.0554
# Epoch [34/500], Loss: 0.1232
# Epoch [34/500], Reconstruction Loss: 0.0407
# Val Loss: 0.1892
# Val Reconstruction Loss: 0.0553
# Epoch [35/500], Loss: 0.1314
# Epoch [35/500], Reconstruction Loss: 0.0463
# Val Loss: 0.1888
# Val Reconstruction Loss: 0.0552
# Epoch [36/500], Loss: 0.1333
# Epoch [36/500], Reconstruction Loss: 0.0456
# Val Loss: 0.1884
# Val Reconstruction Loss: 0.0552
# Epoch [37/500], Loss: 0.1060
# Epoch [37/500], Reconstruction Loss: 0.0346
# Val Loss: 0.1880
# Val Reconstruction Loss: 0.0551
# Epoch [38/500], Loss: 0.1221
# Epoch [38/500], Reconstruction Loss: 0.0404
# Val Loss: 0.1876
# Val Reconstruction Loss: 0.0550
# Epoch [39/500], Loss: 0.1134
# Epoch [39/500], Reconstruction Loss: 0.0369
# Val Loss: 0.1872
# Val Reconstruction Loss: 0.0549
# Epoch [40/500], Loss: 0.1161
# Epoch [40/500], Reconstruction Loss: 0.0378
# Val Loss: 0.1869
# Val Reconstruction Loss: 0.0549
# Epoch [41/500], Loss: 0.1090
# Epoch [41/500], Reconstruction Loss: 0.0338
# Val Loss: 0.1865
# Val Reconstruction Loss: 0.0548
# Epoch [42/500], Loss: 0.1154
# Epoch [42/500], Reconstruction Loss: 0.0374
# Val Loss: 0.1861
# Val Reconstruction Loss: 0.0548
# Epoch [43/500], Loss: 0.1098
# Epoch [43/500], Reconstruction Loss: 0.0357
# Val Loss: 0.1857
# Val Reconstruction Loss: 0.0547
# Epoch [44/500], Loss: 0.1103
# Epoch [44/500], Reconstruction Loss: 0.0352
# Val Loss: 0.1853
# Val Reconstruction Loss: 0.0546
# Epoch [45/500], Loss: 0.1032
# Epoch [45/500], Reconstruction Loss: 0.0332
# Val Loss: 0.1849
# Val Reconstruction Loss: 0.0546
# Epoch [46/500], Loss: 0.1204
# Epoch [46/500], Reconstruction Loss: 0.0428
# Val Loss: 0.1844
# Val Reconstruction Loss: 0.0545
# Epoch [47/500], Loss: 0.1192
# Epoch [47/500], Reconstruction Loss: 0.0405
# Val Loss: 0.1840
# Val Reconstruction Loss: 0.0544
# Epoch [48/500], Loss: 0.1287
# Epoch [48/500], Reconstruction Loss: 0.0464
# Val Loss: 0.1836
# Val Reconstruction Loss: 0.0543
# Epoch [49/500], Loss: 0.1053
# Epoch [49/500], Reconstruction Loss: 0.0336
# Val Loss: 0.1833
# Val Reconstruction Loss: 0.0543
# Epoch [50/500], Loss: 0.1074
# Epoch [50/500], Reconstruction Loss: 0.0346
# Val Loss: 0.1829
# Val Reconstruction Loss: 0.0542
# Epoch [51/500], Loss: 0.1024
# Epoch [51/500], Reconstruction Loss: 0.0329
# Val Loss: 0.1825
# Val Reconstruction Loss: 0.0542
# Epoch [52/500], Loss: 0.1154
# Epoch [52/500], Reconstruction Loss: 0.0385
# Val Loss: 0.1822
# Val Reconstruction Loss: 0.0541
# Epoch [53/500], Loss: 0.1210
# Epoch [53/500], Reconstruction Loss: 0.0439
# Val Loss: 0.1818
# Val Reconstruction Loss: 0.0541
# Epoch [54/500], Loss: 0.1069
# Epoch [54/500], Reconstruction Loss: 0.0347
# Val Loss: 0.1815
# Val Reconstruction Loss: 0.0540
# Epoch [55/500], Loss: 0.1304
# Epoch [55/500], Reconstruction Loss: 0.0489
# Val Loss: 0.1812
# Val Reconstruction Loss: 0.0539
# Epoch [56/500], Loss: 0.1067
# Epoch [56/500], Reconstruction Loss: 0.0362
# Val Loss: 0.1809
# Val Reconstruction Loss: 0.0539
# Epoch [57/500], Loss: 0.1122
# Epoch [57/500], Reconstruction Loss: 0.0374
# Val Loss: 0.1805
# Val Reconstruction Loss: 0.0538
# Epoch [58/500], Loss: 0.0988
# Epoch [58/500], Reconstruction Loss: 0.0320
# Val Loss: 0.1802
# Val Reconstruction Loss: 0.0538
# Epoch [59/500], Loss: 0.1062
# Epoch [59/500], Reconstruction Loss: 0.0362
# Val Loss: 0.1798
# Val Reconstruction Loss: 0.0537
# Epoch [60/500], Loss: 0.1053
# Epoch [60/500], Reconstruction Loss: 0.0348
# Val Loss: 0.1794
# Val Reconstruction Loss: 0.0537
# Epoch [61/500], Loss: 0.1036
# Epoch [61/500], Reconstruction Loss: 0.0339
# Val Loss: 0.1790
# Val Reconstruction Loss: 0.0536
# Epoch [62/500], Loss: 0.0951
# Epoch [62/500], Reconstruction Loss: 0.0307
# Val Loss: 0.1786
# Val Reconstruction Loss: 0.0535
# Epoch [63/500], Loss: 0.0996
# Epoch [63/500], Reconstruction Loss: 0.0326
# Val Loss: 0.1782
# Val Reconstruction Loss: 0.0535
# Epoch [64/500], Loss: 0.0961
# Epoch [64/500], Reconstruction Loss: 0.0316
# Val Loss: 0.1777
# Val Reconstruction Loss: 0.0534
# Epoch [65/500], Loss: 0.0960
# Epoch [65/500], Reconstruction Loss: 0.0315
# Val Loss: 0.1773
# Val Reconstruction Loss: 0.0534
# Epoch [66/500], Loss: 0.1013
# Epoch [66/500], Reconstruction Loss: 0.0329
# Val Loss: 0.1769
# Val Reconstruction Loss: 0.0533
# Epoch [67/500], Loss: 0.0973
# Epoch [67/500], Reconstruction Loss: 0.0316
# Val Loss: 0.1766
# Val Reconstruction Loss: 0.0532
# Epoch [68/500], Loss: 0.1025
# Epoch [68/500], Reconstruction Loss: 0.0332
# Val Loss: 0.1762
# Val Reconstruction Loss: 0.0532
# Epoch [69/500], Loss: 0.1011
# Epoch [69/500], Reconstruction Loss: 0.0334
# Val Loss: 0.1758
# Val Reconstruction Loss: 0.0531
# Epoch [70/500], Loss: 0.1103
# Epoch [70/500], Reconstruction Loss: 0.0382
# Val Loss: 0.1755
# Val Reconstruction Loss: 0.0531
# Epoch [71/500], Loss: 0.0969
# Epoch [71/500], Reconstruction Loss: 0.0322
# Val Loss: 0.1751
# Val Reconstruction Loss: 0.0530
# Epoch [72/500], Loss: 0.1095
# Epoch [72/500], Reconstruction Loss: 0.0384
# Val Loss: 0.1746
# Val Reconstruction Loss: 0.0530
# Epoch [73/500], Loss: 0.1058
# Epoch [73/500], Reconstruction Loss: 0.0359
# Val Loss: 0.1743
# Val Reconstruction Loss: 0.0529
# Epoch [74/500], Loss: 0.1028
# Epoch [74/500], Reconstruction Loss: 0.0342
# Val Loss: 0.1739
# Val Reconstruction Loss: 0.0529
# Epoch [75/500], Loss: 0.0959
# Epoch [75/500], Reconstruction Loss: 0.0308
# Val Loss: 0.1736
# Val Reconstruction Loss: 0.0528
# Epoch [76/500], Loss: 0.1183
# Epoch [76/500], Reconstruction Loss: 0.0417
# Val Loss: 0.1732
# Val Reconstruction Loss: 0.0528
# Epoch [77/500], Loss: 0.1025
# Epoch [77/500], Reconstruction Loss: 0.0344
# Val Loss: 0.1729
# Val Reconstruction Loss: 0.0527
# Epoch [78/500], Loss: 0.0995
# Epoch [78/500], Reconstruction Loss: 0.0327
# Val Loss: 0.1726
# Val Reconstruction Loss: 0.0527
# Epoch [79/500], Loss: 0.0974
# Epoch [79/500], Reconstruction Loss: 0.0324
# Val Loss: 0.1723
# Val Reconstruction Loss: 0.0526
# Epoch [80/500], Loss: 0.1080
# Epoch [80/500], Reconstruction Loss: 0.0365
# Val Loss: 0.1719
# Val Reconstruction Loss: 0.0526
# Epoch [81/500], Loss: 0.1083
# Epoch [81/500], Reconstruction Loss: 0.0376
# Val Loss: 0.1716
# Val Reconstruction Loss: 0.0525
# Epoch [82/500], Loss: 0.1015
# Epoch [82/500], Reconstruction Loss: 0.0350
# Val Loss: 0.1713
# Val Reconstruction Loss: 0.0525
# Epoch [83/500], Loss: 0.0969
# Epoch [83/500], Reconstruction Loss: 0.0331
# Val Loss: 0.1710
# Val Reconstruction Loss: 0.0525
# Epoch [84/500], Loss: 0.0995
# Epoch [84/500], Reconstruction Loss: 0.0327
# Val Loss: 0.1707
# Val Reconstruction Loss: 0.0524
# Epoch [85/500], Loss: 0.0930
# Epoch [85/500], Reconstruction Loss: 0.0318
# Val Loss: 0.1704
# Val Reconstruction Loss: 0.0524
# Epoch [86/500], Loss: 0.1084
# Epoch [86/500], Reconstruction Loss: 0.0383
# Val Loss: 0.1701
# Val Reconstruction Loss: 0.0523
# Epoch [87/500], Loss: 0.0974
# Epoch [87/500], Reconstruction Loss: 0.0328
# Val Loss: 0.1698
# Val Reconstruction Loss: 0.0523
# Epoch [88/500], Loss: 0.1004
# Epoch [88/500], Reconstruction Loss: 0.0355
# Val Loss: 0.1694
# Val Reconstruction Loss: 0.0523
# Epoch [89/500], Loss: 0.0991
# Epoch [89/500], Reconstruction Loss: 0.0344
# Val Loss: 0.1691
# Val Reconstruction Loss: 0.0522
# Epoch [90/500], Loss: 0.1010
# Epoch [90/500], Reconstruction Loss: 0.0354
# Val Loss: 0.1688
# Val Reconstruction Loss: 0.0522
# Epoch [91/500], Loss: 0.0880
# Epoch [91/500], Reconstruction Loss: 0.0293
# Val Loss: 0.1685
# Val Reconstruction Loss: 0.0521
# Epoch [92/500], Loss: 0.0945
# Epoch [92/500], Reconstruction Loss: 0.0328
# Val Loss: 0.1682
# Val Reconstruction Loss: 0.0521
# Epoch [93/500], Loss: 0.0962
# Epoch [93/500], Reconstruction Loss: 0.0327
# Val Loss: 0.1678
# Val Reconstruction Loss: 0.0521
# Epoch [94/500], Loss: 0.0985
# Epoch [94/500], Reconstruction Loss: 0.0334
# Val Loss: 0.1674
# Val Reconstruction Loss: 0.0520
# Epoch [95/500], Loss: 0.0950
# Epoch [95/500], Reconstruction Loss: 0.0329
# Val Loss: 0.1670
# Val Reconstruction Loss: 0.0520
# Epoch [96/500], Loss: 0.0906
# Epoch [96/500], Reconstruction Loss: 0.0306
# Val Loss: 0.1665
# Val Reconstruction Loss: 0.0519
# Epoch [97/500], Loss: 0.1012
# Epoch [97/500], Reconstruction Loss: 0.0344
# Val Loss: 0.1661
# Val Reconstruction Loss: 0.0519
# Epoch [98/500], Loss: 0.1093
# Epoch [98/500], Reconstruction Loss: 0.0399
# Val Loss: 0.1657
# Val Reconstruction Loss: 0.0518
# Epoch [99/500], Loss: 0.1050
# Epoch [99/500], Reconstruction Loss: 0.0409
# Val Loss: 0.1654
# Val Reconstruction Loss: 0.0518
# Epoch [100/500], Loss: 0.0920
# Epoch [100/500], Reconstruction Loss: 0.0314
# Val Loss: 0.1650
# Val Reconstruction Loss: 0.0517
# Epoch [101/500], Loss: 0.1057
# Epoch [101/500], Reconstruction Loss: 0.0388
# Val Loss: 0.1647
# Val Reconstruction Loss: 0.0517
# Epoch [102/500], Loss: 0.0942
# Epoch [102/500], Reconstruction Loss: 0.0332
# Val Loss: 0.1644
# Val Reconstruction Loss: 0.0516
# Epoch [103/500], Loss: 0.1174
# Epoch [103/500], Reconstruction Loss: 0.0469
# Val Loss: 0.1640
# Val Reconstruction Loss: 0.0516
# Epoch [104/500], Loss: 0.0887
# Epoch [104/500], Reconstruction Loss: 0.0305
# Val Loss: 0.1636
# Val Reconstruction Loss: 0.0515
# Epoch [105/500], Loss: 0.1000
# Epoch [105/500], Reconstruction Loss: 0.0367
# Val Loss: 0.1632
# Val Reconstruction Loss: 0.0515
# Epoch [106/500], Loss: 0.0953
# Epoch [106/500], Reconstruction Loss: 0.0347
# Val Loss: 0.1629
# Val Reconstruction Loss: 0.0514
# Epoch [107/500], Loss: 0.0873
# Epoch [107/500], Reconstruction Loss: 0.0307
# Val Loss: 0.1627
# Val Reconstruction Loss: 0.0514
# Epoch [108/500], Loss: 0.0945
# Epoch [108/500], Reconstruction Loss: 0.0341
# Val Loss: 0.1623
# Val Reconstruction Loss: 0.0514
# Epoch [109/500], Loss: 0.0840
# Epoch [109/500], Reconstruction Loss: 0.0294
# Val Loss: 0.1620
# Val Reconstruction Loss: 0.0513
# Epoch [110/500], Loss: 0.0924
# Epoch [110/500], Reconstruction Loss: 0.0324
# Val Loss: 0.1617
# Val Reconstruction Loss: 0.0513
# Epoch [111/500], Loss: 0.0902
# Epoch [111/500], Reconstruction Loss: 0.0321
# Val Loss: 0.1614
# Val Reconstruction Loss: 0.0513
# Epoch [112/500], Loss: 0.0942
# Epoch [112/500], Reconstruction Loss: 0.0333
# Val Loss: 0.1611
# Val Reconstruction Loss: 0.0512
# Epoch [113/500], Loss: 0.0927
# Epoch [113/500], Reconstruction Loss: 0.0336
# Val Loss: 0.1609
# Val Reconstruction Loss: 0.0512
# Epoch [114/500], Loss: 0.0876
# Epoch [114/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1606
# Val Reconstruction Loss: 0.0512
# Epoch [115/500], Loss: 0.0829
# Epoch [115/500], Reconstruction Loss: 0.0291
# Val Loss: 0.1604
# Val Reconstruction Loss: 0.0512
# Epoch [116/500], Loss: 0.0986
# Epoch [116/500], Reconstruction Loss: 0.0391
# Val Loss: 0.1601
# Val Reconstruction Loss: 0.0511
# Epoch [117/500], Loss: 0.0808
# Epoch [117/500], Reconstruction Loss: 0.0287
# Val Loss: 0.1598
# Val Reconstruction Loss: 0.0511
# Epoch [118/500], Loss: 0.0846
# Epoch [118/500], Reconstruction Loss: 0.0292
# Val Loss: 0.1595
# Val Reconstruction Loss: 0.0511
# Epoch [119/500], Loss: 0.1008
# Epoch [119/500], Reconstruction Loss: 0.0359
# Val Loss: 0.1591
# Val Reconstruction Loss: 0.0510
# Epoch [120/500], Loss: 0.0909
# Epoch [120/500], Reconstruction Loss: 0.0319
# Val Loss: 0.1587
# Val Reconstruction Loss: 0.0510
# Epoch [121/500], Loss: 0.0863
# Epoch [121/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1583
# Val Reconstruction Loss: 0.0509
# Epoch [122/500], Loss: 0.0859
# Epoch [122/500], Reconstruction Loss: 0.0318
# Val Loss: 0.1580
# Val Reconstruction Loss: 0.0509
# Epoch [123/500], Loss: 0.0860
# Epoch [123/500], Reconstruction Loss: 0.0305
# Val Loss: 0.1576
# Val Reconstruction Loss: 0.0508
# Epoch [124/500], Loss: 0.0975
# Epoch [124/500], Reconstruction Loss: 0.0357
# Val Loss: 0.1573
# Val Reconstruction Loss: 0.0508
# Epoch [125/500], Loss: 0.0908
# Epoch [125/500], Reconstruction Loss: 0.0329
# Val Loss: 0.1569
# Val Reconstruction Loss: 0.0507
# Epoch [126/500], Loss: 0.0919
# Epoch [126/500], Reconstruction Loss: 0.0331
# Val Loss: 0.1565
# Val Reconstruction Loss: 0.0507
# Epoch [127/500], Loss: 0.0804
# Epoch [127/500], Reconstruction Loss: 0.0293
# Val Loss: 0.1562
# Val Reconstruction Loss: 0.0507
# Epoch [128/500], Loss: 0.0858
# Epoch [128/500], Reconstruction Loss: 0.0311
# Val Loss: 0.1559
# Val Reconstruction Loss: 0.0506
# Epoch [129/500], Loss: 0.0847
# Epoch [129/500], Reconstruction Loss: 0.0314
# Val Loss: 0.1557
# Val Reconstruction Loss: 0.0506
# Epoch [130/500], Loss: 0.1079
# Epoch [130/500], Reconstruction Loss: 0.0437
# Val Loss: 0.1555
# Val Reconstruction Loss: 0.0506
# Epoch [131/500], Loss: 0.0838
# Epoch [131/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1553
# Val Reconstruction Loss: 0.0506
# Epoch [132/500], Loss: 0.0938
# Epoch [132/500], Reconstruction Loss: 0.0356
# Val Loss: 0.1550
# Val Reconstruction Loss: 0.0505
# Epoch [133/500], Loss: 0.0827
# Epoch [133/500], Reconstruction Loss: 0.0299
# Val Loss: 0.1548
# Val Reconstruction Loss: 0.0505
# Epoch [134/500], Loss: 0.0882
# Epoch [134/500], Reconstruction Loss: 0.0334
# Val Loss: 0.1546
# Val Reconstruction Loss: 0.0505
# Epoch [135/500], Loss: 0.0912
# Epoch [135/500], Reconstruction Loss: 0.0344
# Val Loss: 0.1543
# Val Reconstruction Loss: 0.0505
# Epoch [136/500], Loss: 0.0815
# Epoch [136/500], Reconstruction Loss: 0.0301
# Val Loss: 0.1541
# Val Reconstruction Loss: 0.0505
# Epoch [137/500], Loss: 0.0816
# Epoch [137/500], Reconstruction Loss: 0.0295
# Val Loss: 0.1538
# Val Reconstruction Loss: 0.0504
# Epoch [138/500], Loss: 0.0832
# Epoch [138/500], Reconstruction Loss: 0.0308
# Val Loss: 0.1535
# Val Reconstruction Loss: 0.0504
# Epoch [139/500], Loss: 0.1002
# Epoch [139/500], Reconstruction Loss: 0.0382
# Val Loss: 0.1532
# Val Reconstruction Loss: 0.0504
# Epoch [140/500], Loss: 0.0945
# Epoch [140/500], Reconstruction Loss: 0.0385
# Val Loss: 0.1529
# Val Reconstruction Loss: 0.0503
# Epoch [141/500], Loss: 0.0867
# Epoch [141/500], Reconstruction Loss: 0.0333
# Val Loss: 0.1527
# Val Reconstruction Loss: 0.0503
# Epoch [142/500], Loss: 0.0799
# Epoch [142/500], Reconstruction Loss: 0.0292
# Val Loss: 0.1524
# Val Reconstruction Loss: 0.0503
# Epoch [143/500], Loss: 0.0967
# Epoch [143/500], Reconstruction Loss: 0.0373
# Val Loss: 0.1521
# Val Reconstruction Loss: 0.0503
# Epoch [144/500], Loss: 0.0958
# Epoch [144/500], Reconstruction Loss: 0.0351
# Val Loss: 0.1519
# Val Reconstruction Loss: 0.0502
# Epoch [145/500], Loss: 0.0836
# Epoch [145/500], Reconstruction Loss: 0.0311
# Val Loss: 0.1516
# Val Reconstruction Loss: 0.0502
# Epoch [146/500], Loss: 0.0852
# Epoch [146/500], Reconstruction Loss: 0.0321
# Val Loss: 0.1513
# Val Reconstruction Loss: 0.0502
# Epoch [147/500], Loss: 0.0825
# Epoch [147/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1509
# Val Reconstruction Loss: 0.0502
# Epoch [148/500], Loss: 0.0789
# Epoch [148/500], Reconstruction Loss: 0.0297
# Val Loss: 0.1506
# Val Reconstruction Loss: 0.0501
# Epoch [149/500], Loss: 0.0756
# Epoch [149/500], Reconstruction Loss: 0.0287
# Val Loss: 0.1503
# Val Reconstruction Loss: 0.0501
# Epoch [150/500], Loss: 0.0786
# Epoch [150/500], Reconstruction Loss: 0.0286
# Val Loss: 0.1500
# Val Reconstruction Loss: 0.0501
# Epoch [151/500], Loss: 0.1102
# Epoch [151/500], Reconstruction Loss: 0.0449
# Val Loss: 0.1497
# Val Reconstruction Loss: 0.0500
# Epoch [152/500], Loss: 0.0989
# Epoch [152/500], Reconstruction Loss: 0.0384
# Val Loss: 0.1494
# Val Reconstruction Loss: 0.0500
# Epoch [153/500], Loss: 0.0882
# Epoch [153/500], Reconstruction Loss: 0.0340
# Val Loss: 0.1491
# Val Reconstruction Loss: 0.0500
# Epoch [154/500], Loss: 0.0917
# Epoch [154/500], Reconstruction Loss: 0.0360
# Val Loss: 0.1488
# Val Reconstruction Loss: 0.0499
# Epoch [155/500], Loss: 0.0942
# Epoch [155/500], Reconstruction Loss: 0.0369
# Val Loss: 0.1486
# Val Reconstruction Loss: 0.0499
# Epoch [156/500], Loss: 0.0808
# Epoch [156/500], Reconstruction Loss: 0.0311
# Val Loss: 0.1484
# Val Reconstruction Loss: 0.0499
# Epoch [157/500], Loss: 0.0924
# Epoch [157/500], Reconstruction Loss: 0.0346
# Val Loss: 0.1482
# Val Reconstruction Loss: 0.0499
# Epoch [158/500], Loss: 0.0812
# Epoch [158/500], Reconstruction Loss: 0.0311
# Val Loss: 0.1480
# Val Reconstruction Loss: 0.0499
# Epoch [159/500], Loss: 0.0901
# Epoch [159/500], Reconstruction Loss: 0.0356
# Val Loss: 0.1478
# Val Reconstruction Loss: 0.0498
# Epoch [160/500], Loss: 0.0890
# Epoch [160/500], Reconstruction Loss: 0.0347
# Val Loss: 0.1476
# Val Reconstruction Loss: 0.0498
# Epoch [161/500], Loss: 0.0796
# Epoch [161/500], Reconstruction Loss: 0.0299
# Val Loss: 0.1474
# Val Reconstruction Loss: 0.0498
# Epoch [162/500], Loss: 0.0734
# Epoch [162/500], Reconstruction Loss: 0.0281
# Val Loss: 0.1472
# Val Reconstruction Loss: 0.0498
# Epoch [163/500], Loss: 0.0827
# Epoch [163/500], Reconstruction Loss: 0.0329
# Val Loss: 0.1469
# Val Reconstruction Loss: 0.0498
# Epoch [164/500], Loss: 0.0944
# Epoch [164/500], Reconstruction Loss: 0.0403
# Val Loss: 0.1467
# Val Reconstruction Loss: 0.0497
# Epoch [165/500], Loss: 0.0775
# Epoch [165/500], Reconstruction Loss: 0.0294
# Val Loss: 0.1464
# Val Reconstruction Loss: 0.0497
# Epoch [166/500], Loss: 0.0932
# Epoch [166/500], Reconstruction Loss: 0.0392
# Val Loss: 0.1462
# Val Reconstruction Loss: 0.0497
# Epoch [167/500], Loss: 0.0783
# Epoch [167/500], Reconstruction Loss: 0.0305
# Val Loss: 0.1459
# Val Reconstruction Loss: 0.0497
# Epoch [168/500], Loss: 0.0843
# Epoch [168/500], Reconstruction Loss: 0.0334
# Val Loss: 0.1456
# Val Reconstruction Loss: 0.0496
# Epoch [169/500], Loss: 0.0856
# Epoch [169/500], Reconstruction Loss: 0.0334
# Val Loss: 0.1454
# Val Reconstruction Loss: 0.0496
# Epoch [170/500], Loss: 0.0840
# Epoch [170/500], Reconstruction Loss: 0.0331
# Val Loss: 0.1451
# Val Reconstruction Loss: 0.0496
# Epoch [171/500], Loss: 0.0783
# Epoch [171/500], Reconstruction Loss: 0.0304
# Val Loss: 0.1448
# Val Reconstruction Loss: 0.0496
# Epoch [172/500], Loss: 0.0782
# Epoch [172/500], Reconstruction Loss: 0.0309
# Val Loss: 0.1446
# Val Reconstruction Loss: 0.0495
# Epoch [173/500], Loss: 0.0838
# Epoch [173/500], Reconstruction Loss: 0.0348
# Val Loss: 0.1444
# Val Reconstruction Loss: 0.0495
# Epoch [174/500], Loss: 0.0750
# Epoch [174/500], Reconstruction Loss: 0.0292
# Val Loss: 0.1442
# Val Reconstruction Loss: 0.0495
# Epoch [175/500], Loss: 0.0707
# Epoch [175/500], Reconstruction Loss: 0.0276
# Val Loss: 0.1439
# Val Reconstruction Loss: 0.0495
# Epoch [176/500], Loss: 0.0764
# Epoch [176/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1436
# Val Reconstruction Loss: 0.0494
# Epoch [177/500], Loss: 0.0895
# Epoch [177/500], Reconstruction Loss: 0.0391
# Val Loss: 0.1434
# Val Reconstruction Loss: 0.0494
# Epoch [178/500], Loss: 0.0854
# Epoch [178/500], Reconstruction Loss: 0.0349
# Val Loss: 0.1432
# Val Reconstruction Loss: 0.0494
# Epoch [179/500], Loss: 0.0745
# Epoch [179/500], Reconstruction Loss: 0.0291
# Val Loss: 0.1430
# Val Reconstruction Loss: 0.0494
# Epoch [180/500], Loss: 0.0800
# Epoch [180/500], Reconstruction Loss: 0.0325
# Val Loss: 0.1428
# Val Reconstruction Loss: 0.0494
# Epoch [181/500], Loss: 0.0747
# Epoch [181/500], Reconstruction Loss: 0.0296
# Val Loss: 0.1426
# Val Reconstruction Loss: 0.0494
# Epoch [182/500], Loss: 0.0814
# Epoch [182/500], Reconstruction Loss: 0.0320
# Val Loss: 0.1423
# Val Reconstruction Loss: 0.0493
# Epoch [183/500], Loss: 0.0776
# Epoch [183/500], Reconstruction Loss: 0.0315
# Val Loss: 0.1420
# Val Reconstruction Loss: 0.0493
# Epoch [184/500], Loss: 0.0803
# Epoch [184/500], Reconstruction Loss: 0.0315
# Val Loss: 0.1418
# Val Reconstruction Loss: 0.0493
# Epoch [185/500], Loss: 0.0785
# Epoch [185/500], Reconstruction Loss: 0.0315
# Val Loss: 0.1415
# Val Reconstruction Loss: 0.0492
# Epoch [186/500], Loss: 0.0825
# Epoch [186/500], Reconstruction Loss: 0.0340
# Val Loss: 0.1412
# Val Reconstruction Loss: 0.0492
# Epoch [187/500], Loss: 0.0881
# Epoch [187/500], Reconstruction Loss: 0.0396
# Val Loss: 0.1410
# Val Reconstruction Loss: 0.0492
# Epoch [188/500], Loss: 0.0857
# Epoch [188/500], Reconstruction Loss: 0.0343
# Val Loss: 0.1407
# Val Reconstruction Loss: 0.0492
# Epoch [189/500], Loss: 0.0796
# Epoch [189/500], Reconstruction Loss: 0.0325
# Val Loss: 0.1405
# Val Reconstruction Loss: 0.0492
# Epoch [190/500], Loss: 0.0842
# Epoch [190/500], Reconstruction Loss: 0.0350
# Val Loss: 0.1403
# Val Reconstruction Loss: 0.0491
# Epoch [191/500], Loss: 0.0835
# Epoch [191/500], Reconstruction Loss: 0.0380
# Val Loss: 0.1400
# Val Reconstruction Loss: 0.0491
# Epoch [192/500], Loss: 0.0679
# Epoch [192/500], Reconstruction Loss: 0.0276
# Val Loss: 0.1397
# Val Reconstruction Loss: 0.0491
# Epoch [193/500], Loss: 0.0734
# Epoch [193/500], Reconstruction Loss: 0.0302
# Val Loss: 0.1394
# Val Reconstruction Loss: 0.0490
# Epoch [194/500], Loss: 0.0692
# Epoch [194/500], Reconstruction Loss: 0.0283
# Val Loss: 0.1391
# Val Reconstruction Loss: 0.0490
# Epoch [195/500], Loss: 0.0652
# Epoch [195/500], Reconstruction Loss: 0.0268
# Val Loss: 0.1388
# Val Reconstruction Loss: 0.0490
# Epoch [196/500], Loss: 0.0777
# Epoch [196/500], Reconstruction Loss: 0.0333
# Val Loss: 0.1385
# Val Reconstruction Loss: 0.0490
# Epoch [197/500], Loss: 0.0665
# Epoch [197/500], Reconstruction Loss: 0.0272
# Val Loss: 0.1382
# Val Reconstruction Loss: 0.0490
# Epoch [198/500], Loss: 0.0745
# Epoch [198/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1379
# Val Reconstruction Loss: 0.0490
# Epoch [199/500], Loss: 0.0699
# Epoch [199/500], Reconstruction Loss: 0.0290
# Val Loss: 0.1376
# Val Reconstruction Loss: 0.0489
# Epoch [200/500], Loss: 0.0705
# Epoch [200/500], Reconstruction Loss: 0.0288
# Val Loss: 0.1374
# Val Reconstruction Loss: 0.0489
# Epoch [201/500], Loss: 0.0672
# Epoch [201/500], Reconstruction Loss: 0.0279
# Val Loss: 0.1371
# Val Reconstruction Loss: 0.0489
# Epoch [202/500], Loss: 0.0709
# Epoch [202/500], Reconstruction Loss: 0.0291
# Val Loss: 0.1368
# Val Reconstruction Loss: 0.0489
# Epoch [203/500], Loss: 0.0783
# Epoch [203/500], Reconstruction Loss: 0.0329
# Val Loss: 0.1365
# Val Reconstruction Loss: 0.0489
# Epoch [204/500], Loss: 0.0687
# Epoch [204/500], Reconstruction Loss: 0.0279
# Val Loss: 0.1363
# Val Reconstruction Loss: 0.0489
# Epoch [205/500], Loss: 0.0758
# Epoch [205/500], Reconstruction Loss: 0.0315
# Val Loss: 0.1361
# Val Reconstruction Loss: 0.0489
# Epoch [206/500], Loss: 0.0728
# Epoch [206/500], Reconstruction Loss: 0.0313
# Val Loss: 0.1358
# Val Reconstruction Loss: 0.0488
# Epoch [207/500], Loss: 0.0780
# Epoch [207/500], Reconstruction Loss: 0.0328
# Val Loss: 0.1356
# Val Reconstruction Loss: 0.0488
# Epoch [208/500], Loss: 0.0825
# Epoch [208/500], Reconstruction Loss: 0.0372
# Val Loss: 0.1353
# Val Reconstruction Loss: 0.0488
# Epoch [209/500], Loss: 0.0809
# Epoch [209/500], Reconstruction Loss: 0.0339
# Val Loss: 0.1351
# Val Reconstruction Loss: 0.0488
# Epoch [210/500], Loss: 0.0782
# Epoch [210/500], Reconstruction Loss: 0.0326
# Val Loss: 0.1349
# Val Reconstruction Loss: 0.0488
# Epoch [211/500], Loss: 0.0683
# Epoch [211/500], Reconstruction Loss: 0.0287
# Val Loss: 0.1346
# Val Reconstruction Loss: 0.0487
# Epoch [212/500], Loss: 0.0682
# Epoch [212/500], Reconstruction Loss: 0.0291
# Val Loss: 0.1343
# Val Reconstruction Loss: 0.0487
# Epoch [213/500], Loss: 0.0656
# Epoch [213/500], Reconstruction Loss: 0.0272
# Val Loss: 0.1340
# Val Reconstruction Loss: 0.0487
# Epoch [214/500], Loss: 0.0764
# Epoch [214/500], Reconstruction Loss: 0.0322
# Val Loss: 0.1337
# Val Reconstruction Loss: 0.0487
# Epoch [215/500], Loss: 0.0716
# Epoch [215/500], Reconstruction Loss: 0.0308
# Val Loss: 0.1335
# Val Reconstruction Loss: 0.0487
# Epoch [216/500], Loss: 0.0891
# Epoch [216/500], Reconstruction Loss: 0.0380
# Val Loss: 0.1333
# Val Reconstruction Loss: 0.0487
# Epoch [217/500], Loss: 0.0795
# Epoch [217/500], Reconstruction Loss: 0.0331
# Val Loss: 0.1331
# Val Reconstruction Loss: 0.0486
# Epoch [218/500], Loss: 0.0684
# Epoch [218/500], Reconstruction Loss: 0.0291
# Val Loss: 0.1328
# Val Reconstruction Loss: 0.0486
# Epoch [219/500], Loss: 0.0696
# Epoch [219/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1326
# Val Reconstruction Loss: 0.0486
# Epoch [220/500], Loss: 0.0849
# Epoch [220/500], Reconstruction Loss: 0.0387
# Val Loss: 0.1324
# Val Reconstruction Loss: 0.0486
# Epoch [221/500], Loss: 0.0767
# Epoch [221/500], Reconstruction Loss: 0.0325
# Val Loss: 0.1322
# Val Reconstruction Loss: 0.0486
# Epoch [222/500], Loss: 0.0787
# Epoch [222/500], Reconstruction Loss: 0.0348
# Val Loss: 0.1320
# Val Reconstruction Loss: 0.0486
# Epoch [223/500], Loss: 0.0697
# Epoch [223/500], Reconstruction Loss: 0.0298
# Val Loss: 0.1319
# Val Reconstruction Loss: 0.0486
# Epoch [224/500], Loss: 0.0668
# Epoch [224/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1317
# Val Reconstruction Loss: 0.0486
# Epoch [225/500], Loss: 0.0663
# Epoch [225/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1316
# Val Reconstruction Loss: 0.0485
# Epoch [226/500], Loss: 0.0718
# Epoch [226/500], Reconstruction Loss: 0.0320
# Val Loss: 0.1314
# Val Reconstruction Loss: 0.0485
# Epoch [227/500], Loss: 0.0818
# Epoch [227/500], Reconstruction Loss: 0.0374
# Val Loss: 0.1312
# Val Reconstruction Loss: 0.0485
# Epoch [228/500], Loss: 0.0656
# Epoch [228/500], Reconstruction Loss: 0.0281
# Val Loss: 0.1311
# Val Reconstruction Loss: 0.0485
# Epoch [229/500], Loss: 0.0817
# Epoch [229/500], Reconstruction Loss: 0.0361
# Val Loss: 0.1309
# Val Reconstruction Loss: 0.0485
# Epoch [230/500], Loss: 0.0784
# Epoch [230/500], Reconstruction Loss: 0.0347
# Val Loss: 0.1307
# Val Reconstruction Loss: 0.0485
# Epoch [231/500], Loss: 0.0658
# Epoch [231/500], Reconstruction Loss: 0.0292
# Val Loss: 0.1306
# Val Reconstruction Loss: 0.0485
# Epoch [232/500], Loss: 0.0694
# Epoch [232/500], Reconstruction Loss: 0.0316
# Val Loss: 0.1304
# Val Reconstruction Loss: 0.0485
# Epoch [233/500], Loss: 0.0742
# Epoch [233/500], Reconstruction Loss: 0.0340
# Val Loss: 0.1302
# Val Reconstruction Loss: 0.0485
# Epoch [234/500], Loss: 0.0672
# Epoch [234/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1300
# Val Reconstruction Loss: 0.0485
# Epoch [235/500], Loss: 0.0639
# Epoch [235/500], Reconstruction Loss: 0.0279
# Val Loss: 0.1298
# Val Reconstruction Loss: 0.0485
# Epoch [236/500], Loss: 0.0615
# Epoch [236/500], Reconstruction Loss: 0.0269
# Val Loss: 0.1296
# Val Reconstruction Loss: 0.0485
# Epoch [237/500], Loss: 0.0668
# Epoch [237/500], Reconstruction Loss: 0.0304
# Val Loss: 0.1293
# Val Reconstruction Loss: 0.0485
# Epoch [238/500], Loss: 0.0682
# Epoch [238/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1291
# Val Reconstruction Loss: 0.0485
# Epoch [239/500], Loss: 0.0632
# Epoch [239/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1289
# Val Reconstruction Loss: 0.0484
# Epoch [240/500], Loss: 0.0685
# Epoch [240/500], Reconstruction Loss: 0.0296
# Val Loss: 0.1287
# Val Reconstruction Loss: 0.0484
# Epoch [241/500], Loss: 0.0670
# Epoch [241/500], Reconstruction Loss: 0.0297
# Val Loss: 0.1284
# Val Reconstruction Loss: 0.0484
# Epoch [242/500], Loss: 0.0649
# Epoch [242/500], Reconstruction Loss: 0.0295
# Val Loss: 0.1282
# Val Reconstruction Loss: 0.0484
# Epoch [243/500], Loss: 0.0610
# Epoch [243/500], Reconstruction Loss: 0.0271
# Val Loss: 0.1280
# Val Reconstruction Loss: 0.0484
# Epoch [244/500], Loss: 0.0617
# Epoch [244/500], Reconstruction Loss: 0.0276
# Val Loss: 0.1278
# Val Reconstruction Loss: 0.0484
# Epoch [245/500], Loss: 0.0607
# Epoch [245/500], Reconstruction Loss: 0.0278
# Val Loss: 0.1276
# Val Reconstruction Loss: 0.0484
# Epoch [246/500], Loss: 0.0655
# Epoch [246/500], Reconstruction Loss: 0.0299
# Val Loss: 0.1274
# Val Reconstruction Loss: 0.0484
# Epoch [247/500], Loss: 0.0773
# Epoch [247/500], Reconstruction Loss: 0.0347
# Val Loss: 0.1272
# Val Reconstruction Loss: 0.0484
# Epoch [248/500], Loss: 0.0602
# Epoch [248/500], Reconstruction Loss: 0.0273
# Val Loss: 0.1270
# Val Reconstruction Loss: 0.0484
# Epoch [249/500], Loss: 0.0676
# Epoch [249/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1269
# Val Reconstruction Loss: 0.0484
# Epoch [250/500], Loss: 0.0639
# Epoch [250/500], Reconstruction Loss: 0.0290
# Val Loss: 0.1267
# Val Reconstruction Loss: 0.0484
# Epoch [251/500], Loss: 0.0735
# Epoch [251/500], Reconstruction Loss: 0.0366
# Val Loss: 0.1265
# Val Reconstruction Loss: 0.0484
# Epoch [252/500], Loss: 0.0594
# Epoch [252/500], Reconstruction Loss: 0.0272
# Val Loss: 0.1263
# Val Reconstruction Loss: 0.0484
# Epoch [253/500], Loss: 0.0712
# Epoch [253/500], Reconstruction Loss: 0.0320
# Val Loss: 0.1262
# Val Reconstruction Loss: 0.0484
# Epoch [254/500], Loss: 0.0624
# Epoch [254/500], Reconstruction Loss: 0.0288
# Val Loss: 0.1260
# Val Reconstruction Loss: 0.0484
# Epoch [255/500], Loss: 0.0673
# Epoch [255/500], Reconstruction Loss: 0.0314
# Val Loss: 0.1258
# Val Reconstruction Loss: 0.0484
# Epoch [256/500], Loss: 0.0743
# Epoch [256/500], Reconstruction Loss: 0.0335
# Val Loss: 0.1257
# Val Reconstruction Loss: 0.0484
# Epoch [257/500], Loss: 0.0635
# Epoch [257/500], Reconstruction Loss: 0.0286
# Val Loss: 0.1256
# Val Reconstruction Loss: 0.0484
# Epoch [258/500], Loss: 0.0789
# Epoch [258/500], Reconstruction Loss: 0.0364
# Val Loss: 0.1254
# Val Reconstruction Loss: 0.0484
# Epoch [259/500], Loss: 0.0622
# Epoch [259/500], Reconstruction Loss: 0.0286
# Val Loss: 0.1253
# Val Reconstruction Loss: 0.0484
# Epoch [260/500], Loss: 0.0797
# Epoch [260/500], Reconstruction Loss: 0.0382
# Val Loss: 0.1251
# Val Reconstruction Loss: 0.0484
# Epoch [261/500], Loss: 0.0583
# Epoch [261/500], Reconstruction Loss: 0.0270
# Val Loss: 0.1250
# Val Reconstruction Loss: 0.0483
# Epoch [262/500], Loss: 0.0658
# Epoch [262/500], Reconstruction Loss: 0.0304
# Val Loss: 0.1248
# Val Reconstruction Loss: 0.0483
# Epoch [263/500], Loss: 0.0664
# Epoch [263/500], Reconstruction Loss: 0.0314
# Val Loss: 0.1246
# Val Reconstruction Loss: 0.0483
# Epoch [264/500], Loss: 0.0639
# Epoch [264/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1244
# Val Reconstruction Loss: 0.0483
# Epoch [265/500], Loss: 0.0701
# Epoch [265/500], Reconstruction Loss: 0.0334
# Val Loss: 0.1243
# Val Reconstruction Loss: 0.0483
# Epoch [266/500], Loss: 0.0623
# Epoch [266/500], Reconstruction Loss: 0.0301
# Val Loss: 0.1241
# Val Reconstruction Loss: 0.0483
# Epoch [267/500], Loss: 0.0600
# Epoch [267/500], Reconstruction Loss: 0.0279
# Val Loss: 0.1239
# Val Reconstruction Loss: 0.0483
# Epoch [268/500], Loss: 0.0747
# Epoch [268/500], Reconstruction Loss: 0.0346
# Val Loss: 0.1237
# Val Reconstruction Loss: 0.0483
# Epoch [269/500], Loss: 0.0660
# Epoch [269/500], Reconstruction Loss: 0.0322
# Val Loss: 0.1235
# Val Reconstruction Loss: 0.0483
# Epoch [270/500], Loss: 0.0585
# Epoch [270/500], Reconstruction Loss: 0.0278
# Val Loss: 0.1233
# Val Reconstruction Loss: 0.0483
# Epoch [271/500], Loss: 0.0643
# Epoch [271/500], Reconstruction Loss: 0.0307
# Val Loss: 0.1232
# Val Reconstruction Loss: 0.0483
# Epoch [272/500], Loss: 0.0619
# Epoch [272/500], Reconstruction Loss: 0.0292
# Val Loss: 0.1231
# Val Reconstruction Loss: 0.0483
# Epoch [273/500], Loss: 0.0735
# Epoch [273/500], Reconstruction Loss: 0.0358
# Val Loss: 0.1229
# Val Reconstruction Loss: 0.0483
# Epoch [274/500], Loss: 0.0613
# Epoch [274/500], Reconstruction Loss: 0.0288
# Val Loss: 0.1228
# Val Reconstruction Loss: 0.0483
# Epoch [275/500], Loss: 0.0601
# Epoch [275/500], Reconstruction Loss: 0.0287
# Val Loss: 0.1226
# Val Reconstruction Loss: 0.0483
# Epoch [276/500], Loss: 0.0633
# Epoch [276/500], Reconstruction Loss: 0.0307
# Val Loss: 0.1224
# Val Reconstruction Loss: 0.0483
# Epoch [277/500], Loss: 0.0739
# Epoch [277/500], Reconstruction Loss: 0.0357
# Val Loss: 0.1223
# Val Reconstruction Loss: 0.0483
# Epoch [278/500], Loss: 0.0750
# Epoch [278/500], Reconstruction Loss: 0.0353
# Val Loss: 0.1222
# Val Reconstruction Loss: 0.0483
# Epoch [279/500], Loss: 0.0554
# Epoch [279/500], Reconstruction Loss: 0.0264
# Val Loss: 0.1221
# Val Reconstruction Loss: 0.0483
# Epoch [280/500], Loss: 0.0568
# Epoch [280/500], Reconstruction Loss: 0.0276
# Val Loss: 0.1219
# Val Reconstruction Loss: 0.0483
# Epoch [281/500], Loss: 0.0655
# Epoch [281/500], Reconstruction Loss: 0.0330
# Val Loss: 0.1217
# Val Reconstruction Loss: 0.0483
# Epoch [282/500], Loss: 0.0624
# Epoch [282/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1215
# Val Reconstruction Loss: 0.0483
# Epoch [283/500], Loss: 0.0633
# Epoch [283/500], Reconstruction Loss: 0.0297
# Val Loss: 0.1214
# Val Reconstruction Loss: 0.0483
# Epoch [284/500], Loss: 0.0580
# Epoch [284/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1211
# Val Reconstruction Loss: 0.0483
# Epoch [285/500], Loss: 0.0665
# Epoch [285/500], Reconstruction Loss: 0.0327
# Val Loss: 0.1209
# Val Reconstruction Loss: 0.0483
# Epoch [286/500], Loss: 0.0619
# Epoch [286/500], Reconstruction Loss: 0.0309
# Val Loss: 0.1207
# Val Reconstruction Loss: 0.0483
# Epoch [287/500], Loss: 0.0588
# Epoch [287/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1205
# Val Reconstruction Loss: 0.0483
# Epoch [288/500], Loss: 0.0564
# Epoch [288/500], Reconstruction Loss: 0.0278
# Val Loss: 0.1203
# Val Reconstruction Loss: 0.0483
# Epoch [289/500], Loss: 0.0788
# Epoch [289/500], Reconstruction Loss: 0.0384
# Val Loss: 0.1202
# Val Reconstruction Loss: 0.0483
# Epoch [290/500], Loss: 0.0680
# Epoch [290/500], Reconstruction Loss: 0.0339
# Val Loss: 0.1200
# Val Reconstruction Loss: 0.0483
# Epoch [291/500], Loss: 0.0659
# Epoch [291/500], Reconstruction Loss: 0.0316
# Val Loss: 0.1199
# Val Reconstruction Loss: 0.0483
# Epoch [292/500], Loss: 0.0564
# Epoch [292/500], Reconstruction Loss: 0.0275
# Val Loss: 0.1197
# Val Reconstruction Loss: 0.0483
# Epoch [293/500], Loss: 0.0776
# Epoch [293/500], Reconstruction Loss: 0.0376
# Val Loss: 0.1195
# Val Reconstruction Loss: 0.0483
# Epoch [294/500], Loss: 0.0583
# Epoch [294/500], Reconstruction Loss: 0.0283
# Val Loss: 0.1193
# Val Reconstruction Loss: 0.0483
# Epoch [295/500], Loss: 0.0688
# Epoch [295/500], Reconstruction Loss: 0.0336
# Val Loss: 0.1191
# Val Reconstruction Loss: 0.0483
# Epoch [296/500], Loss: 0.0637
# Epoch [296/500], Reconstruction Loss: 0.0309
# Val Loss: 0.1190
# Val Reconstruction Loss: 0.0483
# Epoch [297/500], Loss: 0.0693
# Epoch [297/500], Reconstruction Loss: 0.0347
# Val Loss: 0.1187
# Val Reconstruction Loss: 0.0482
# Epoch [298/500], Loss: 0.0723
# Epoch [298/500], Reconstruction Loss: 0.0351
# Val Loss: 0.1186
# Val Reconstruction Loss: 0.0482
# Epoch [299/500], Loss: 0.0685
# Epoch [299/500], Reconstruction Loss: 0.0346
# Val Loss: 0.1184
# Val Reconstruction Loss: 0.0482
# Epoch [300/500], Loss: 0.0591
# Epoch [300/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1183
# Val Reconstruction Loss: 0.0482
# Epoch [301/500], Loss: 0.0789
# Epoch [301/500], Reconstruction Loss: 0.0399
# Val Loss: 0.1182
# Val Reconstruction Loss: 0.0482
# Epoch [302/500], Loss: 0.0523
# Epoch [302/500], Reconstruction Loss: 0.0263
# Val Loss: 0.1181
# Val Reconstruction Loss: 0.0482
# Epoch [303/500], Loss: 0.0560
# Epoch [303/500], Reconstruction Loss: 0.0280
# Val Loss: 0.1180
# Val Reconstruction Loss: 0.0482
# Epoch [304/500], Loss: 0.0636
# Epoch [304/500], Reconstruction Loss: 0.0306
# Val Loss: 0.1179
# Val Reconstruction Loss: 0.0482
# Epoch [305/500], Loss: 0.0522
# Epoch [305/500], Reconstruction Loss: 0.0262
# Val Loss: 0.1177
# Val Reconstruction Loss: 0.0482
# Epoch [306/500], Loss: 0.0525
# Epoch [306/500], Reconstruction Loss: 0.0269
# Val Loss: 0.1174
# Val Reconstruction Loss: 0.0482
# Epoch [307/500], Loss: 0.0557
# Epoch [307/500], Reconstruction Loss: 0.0282
# Val Loss: 0.1173
# Val Reconstruction Loss: 0.0482
# Epoch [308/500], Loss: 0.0626
# Epoch [308/500], Reconstruction Loss: 0.0306
# Val Loss: 0.1171
# Val Reconstruction Loss: 0.0482
# Epoch [309/500], Loss: 0.0765
# Epoch [309/500], Reconstruction Loss: 0.0393
# Val Loss: 0.1169
# Val Reconstruction Loss: 0.0482
# Epoch [310/500], Loss: 0.0577
# Epoch [310/500], Reconstruction Loss: 0.0295
# Val Loss: 0.1167
# Val Reconstruction Loss: 0.0482
# Epoch [311/500], Loss: 0.0650
# Epoch [311/500], Reconstruction Loss: 0.0362
# Val Loss: 0.1166
# Val Reconstruction Loss: 0.0482
# Epoch [312/500], Loss: 0.0573
# Epoch [312/500], Reconstruction Loss: 0.0297
# Val Loss: 0.1165
# Val Reconstruction Loss: 0.0482
# Epoch [313/500], Loss: 0.0591
# Epoch [313/500], Reconstruction Loss: 0.0304
# Val Loss: 0.1163
# Val Reconstruction Loss: 0.0482
# Epoch [314/500], Loss: 0.0578
# Epoch [314/500], Reconstruction Loss: 0.0293
# Val Loss: 0.1162
# Val Reconstruction Loss: 0.0482
# Epoch [315/500], Loss: 0.0630
# Epoch [315/500], Reconstruction Loss: 0.0328
# Val Loss: 0.1161
# Val Reconstruction Loss: 0.0482
# Epoch [316/500], Loss: 0.0637
# Epoch [316/500], Reconstruction Loss: 0.0315
# Val Loss: 0.1159
# Val Reconstruction Loss: 0.0482
# Epoch [317/500], Loss: 0.0575
# Epoch [317/500], Reconstruction Loss: 0.0298
# Val Loss: 0.1157
# Val Reconstruction Loss: 0.0482
# Epoch [318/500], Loss: 0.0542
# Epoch [318/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1155
# Val Reconstruction Loss: 0.0482
# Epoch [319/500], Loss: 0.0574
# Epoch [319/500], Reconstruction Loss: 0.0296
# Val Loss: 0.1154
# Val Reconstruction Loss: 0.0482
# Epoch [320/500], Loss: 0.0588
# Epoch [320/500], Reconstruction Loss: 0.0305
# Val Loss: 0.1153
# Val Reconstruction Loss: 0.0482
# Epoch [321/500], Loss: 0.0595
# Epoch [321/500], Reconstruction Loss: 0.0292
# Val Loss: 0.1151
# Val Reconstruction Loss: 0.0482
# Epoch [322/500], Loss: 0.0566
# Epoch [322/500], Reconstruction Loss: 0.0291
# Val Loss: 0.1150
# Val Reconstruction Loss: 0.0482
# Epoch [323/500], Loss: 0.0587
# Epoch [323/500], Reconstruction Loss: 0.0310
# Val Loss: 0.1148
# Val Reconstruction Loss: 0.0482
# Epoch [324/500], Loss: 0.0514
# Epoch [324/500], Reconstruction Loss: 0.0266
# Val Loss: 0.1146
# Val Reconstruction Loss: 0.0482
# Epoch [325/500], Loss: 0.0629
# Epoch [325/500], Reconstruction Loss: 0.0335
# Val Loss: 0.1145
# Val Reconstruction Loss: 0.0482
# Epoch [326/500], Loss: 0.0604
# Epoch [326/500], Reconstruction Loss: 0.0314
# Val Loss: 0.1143
# Val Reconstruction Loss: 0.0482
# Epoch [327/500], Loss: 0.0523
# Epoch [327/500], Reconstruction Loss: 0.0277
# Val Loss: 0.1141
# Val Reconstruction Loss: 0.0482
# Epoch [328/500], Loss: 0.0578
# Epoch [328/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1140
# Val Reconstruction Loss: 0.0482
# Epoch [329/500], Loss: 0.0570
# Epoch [329/500], Reconstruction Loss: 0.0300
# Val Loss: 0.1138
# Val Reconstruction Loss: 0.0482
# Epoch [330/500], Loss: 0.0573
# Epoch [330/500], Reconstruction Loss: 0.0308
# Val Loss: 0.1137
# Val Reconstruction Loss: 0.0482
# Epoch [331/500], Loss: 0.0516
# Epoch [331/500], Reconstruction Loss: 0.0276
# Val Loss: 0.1135
# Val Reconstruction Loss: 0.0482
# Epoch [332/500], Loss: 0.0622
# Epoch [332/500], Reconstruction Loss: 0.0353
# Val Loss: 0.1134
# Val Reconstruction Loss: 0.0482
# Epoch [333/500], Loss: 0.0539
# Epoch [333/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1133
# Val Reconstruction Loss: 0.0482
# Epoch [334/500], Loss: 0.0501
# Epoch [334/500], Reconstruction Loss: 0.0266
# Val Loss: 0.1131
# Val Reconstruction Loss: 0.0482
# Epoch [335/500], Loss: 0.0507
# Epoch [335/500], Reconstruction Loss: 0.0271
# Val Loss: 0.1130
# Val Reconstruction Loss: 0.0482
# Epoch [336/500], Loss: 0.0577
# Epoch [336/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1128
# Val Reconstruction Loss: 0.0482
# Epoch [337/500], Loss: 0.0572
# Epoch [337/500], Reconstruction Loss: 0.0313
# Val Loss: 0.1126
# Val Reconstruction Loss: 0.0482
# Epoch [338/500], Loss: 0.0570
# Epoch [338/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1125
# Val Reconstruction Loss: 0.0482
# Epoch [339/500], Loss: 0.0573
# Epoch [339/500], Reconstruction Loss: 0.0311
# Val Loss: 0.1124
# Val Reconstruction Loss: 0.0482
# Epoch [340/500], Loss: 0.0515
# Epoch [340/500], Reconstruction Loss: 0.0283
# Val Loss: 0.1122
# Val Reconstruction Loss: 0.0482
# Epoch [341/500], Loss: 0.0572
# Epoch [341/500], Reconstruction Loss: 0.0302
# Val Loss: 0.1121
# Val Reconstruction Loss: 0.0482
# Epoch [342/500], Loss: 0.0495
# Epoch [342/500], Reconstruction Loss: 0.0267
# Val Loss: 0.1120
# Val Reconstruction Loss: 0.0482
# Epoch [343/500], Loss: 0.0616
# Epoch [343/500], Reconstruction Loss: 0.0320
# Val Loss: 0.1118
# Val Reconstruction Loss: 0.0482
# Epoch [344/500], Loss: 0.0590
# Epoch [344/500], Reconstruction Loss: 0.0312
# Val Loss: 0.1117
# Val Reconstruction Loss: 0.0482
# Epoch [345/500], Loss: 0.0545
# Epoch [345/500], Reconstruction Loss: 0.0297
# Val Loss: 0.1115
# Val Reconstruction Loss: 0.0482
# Epoch [346/500], Loss: 0.0673
# Epoch [346/500], Reconstruction Loss: 0.0352
# Val Loss: 0.1114
# Val Reconstruction Loss: 0.0482
# Epoch [347/500], Loss: 0.0510
# Epoch [347/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1112
# Val Reconstruction Loss: 0.0482
# Epoch [348/500], Loss: 0.0504
# Epoch [348/500], Reconstruction Loss: 0.0274
# Val Loss: 0.1111
# Val Reconstruction Loss: 0.0482
# Epoch [349/500], Loss: 0.0489
# Epoch [349/500], Reconstruction Loss: 0.0268
# Val Loss: 0.1109
# Val Reconstruction Loss: 0.0482
# Epoch [350/500], Loss: 0.0508
# Epoch [350/500], Reconstruction Loss: 0.0277
# Val Loss: 0.1108
# Val Reconstruction Loss: 0.0482
# Epoch [351/500], Loss: 0.0564
# Epoch [351/500], Reconstruction Loss: 0.0314
# Val Loss: 0.1106
# Val Reconstruction Loss: 0.0482
# Epoch [352/500], Loss: 0.0613
# Epoch [352/500], Reconstruction Loss: 0.0320
# Val Loss: 0.1105
# Val Reconstruction Loss: 0.0482
# Epoch [353/500], Loss: 0.0625
# Epoch [353/500], Reconstruction Loss: 0.0349
# Val Loss: 0.1103
# Val Reconstruction Loss: 0.0482
# Epoch [354/500], Loss: 0.0506
# Epoch [354/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1102
# Val Reconstruction Loss: 0.0482
# Epoch [355/500], Loss: 0.0625
# Epoch [355/500], Reconstruction Loss: 0.0356
# Val Loss: 0.1100
# Val Reconstruction Loss: 0.0482
# Epoch [356/500], Loss: 0.0630
# Epoch [356/500], Reconstruction Loss: 0.0355
# Val Loss: 0.1099
# Val Reconstruction Loss: 0.0482
# Epoch [357/500], Loss: 0.0516
# Epoch [357/500], Reconstruction Loss: 0.0285
# Val Loss: 0.1098
# Val Reconstruction Loss: 0.0482
# Epoch [358/500], Loss: 0.0487
# Epoch [358/500], Reconstruction Loss: 0.0274
# Val Loss: 0.1096
# Val Reconstruction Loss: 0.0482
# Epoch [359/500], Loss: 0.0544
# Epoch [359/500], Reconstruction Loss: 0.0299
# Val Loss: 0.1095
# Val Reconstruction Loss: 0.0482
# Epoch [360/500], Loss: 0.0548
# Epoch [360/500], Reconstruction Loss: 0.0309
# Val Loss: 0.1094
# Val Reconstruction Loss: 0.0482
# Epoch [361/500], Loss: 0.0662
# Epoch [361/500], Reconstruction Loss: 0.0377
# Val Loss: 0.1093
# Val Reconstruction Loss: 0.0482
# Epoch [362/500], Loss: 0.0681
# Epoch [362/500], Reconstruction Loss: 0.0373
# Val Loss: 0.1092
# Val Reconstruction Loss: 0.0482
# Epoch [363/500], Loss: 0.0526
# Epoch [363/500], Reconstruction Loss: 0.0293
# Val Loss: 0.1091
# Val Reconstruction Loss: 0.0482
# Epoch [364/500], Loss: 0.0484
# Epoch [364/500], Reconstruction Loss: 0.0277
# Val Loss: 0.1090
# Val Reconstruction Loss: 0.0482
# Epoch [365/500], Loss: 0.0592
# Epoch [365/500], Reconstruction Loss: 0.0324
# Val Loss: 0.1089
# Val Reconstruction Loss: 0.0482
# Epoch [366/500], Loss: 0.0648
# Epoch [366/500], Reconstruction Loss: 0.0390
# Val Loss: 0.1088
# Val Reconstruction Loss: 0.0483
# Epoch [367/500], Loss: 0.0498
# Epoch [367/500], Reconstruction Loss: 0.0281
# Val Loss: 0.1087
# Val Reconstruction Loss: 0.0483
# Epoch [368/500], Loss: 0.0612
# Epoch [368/500], Reconstruction Loss: 0.0337
# Val Loss: 0.1086
# Val Reconstruction Loss: 0.0483
# Epoch [369/500], Loss: 0.0489
# Epoch [369/500], Reconstruction Loss: 0.0279
# Val Loss: 0.1084
# Val Reconstruction Loss: 0.0483
# Epoch [370/500], Loss: 0.0483
# Epoch [370/500], Reconstruction Loss: 0.0273
# Val Loss: 0.1083
# Val Reconstruction Loss: 0.0483
# Epoch [371/500], Loss: 0.0577
# Epoch [371/500], Reconstruction Loss: 0.0312
# Val Loss: 0.1082
# Val Reconstruction Loss: 0.0483
# Epoch [372/500], Loss: 0.0636
# Epoch [372/500], Reconstruction Loss: 0.0350
# Val Loss: 0.1080
# Val Reconstruction Loss: 0.0483
# Epoch [373/500], Loss: 0.0650
# Epoch [373/500], Reconstruction Loss: 0.0383
# Val Loss: 0.1078
# Val Reconstruction Loss: 0.0483
# Epoch [374/500], Loss: 0.0500
# Epoch [374/500], Reconstruction Loss: 0.0283
# Val Loss: 0.1077
# Val Reconstruction Loss: 0.0483
# Epoch [375/500], Loss: 0.0580
# Epoch [375/500], Reconstruction Loss: 0.0334
# Val Loss: 0.1076
# Val Reconstruction Loss: 0.0483
# Epoch [376/500], Loss: 0.0494
# Epoch [376/500], Reconstruction Loss: 0.0283
# Val Loss: 0.1074
# Val Reconstruction Loss: 0.0483
# Epoch [377/500], Loss: 0.0555
# Epoch [377/500], Reconstruction Loss: 0.0319
# Val Loss: 0.1073
# Val Reconstruction Loss: 0.0483
# Epoch [378/500], Loss: 0.0539
# Epoch [378/500], Reconstruction Loss: 0.0295
# Val Loss: 0.1071
# Val Reconstruction Loss: 0.0483
# Epoch [379/500], Loss: 0.0487
# Epoch [379/500], Reconstruction Loss: 0.0280
# Val Loss: 0.1069
# Val Reconstruction Loss: 0.0483
# Epoch [380/500], Loss: 0.0555
# Epoch [380/500], Reconstruction Loss: 0.0320
# Val Loss: 0.1068
# Val Reconstruction Loss: 0.0483
# Epoch [381/500], Loss: 0.0591
# Epoch [381/500], Reconstruction Loss: 0.0347
# Val Loss: 0.1066
# Val Reconstruction Loss: 0.0483
# Epoch [382/500], Loss: 0.0543
# Epoch [382/500], Reconstruction Loss: 0.0321
# Val Loss: 0.1065
# Val Reconstruction Loss: 0.0483
# Epoch [383/500], Loss: 0.0614
# Epoch [383/500], Reconstruction Loss: 0.0376
# Val Loss: 0.1064
# Val Reconstruction Loss: 0.0483
# Epoch [384/500], Loss: 0.0642
# Epoch [384/500], Reconstruction Loss: 0.0367
# Val Loss: 0.1063
# Val Reconstruction Loss: 0.0483
# Epoch [385/500], Loss: 0.0463
# Epoch [385/500], Reconstruction Loss: 0.0267
# Val Loss: 0.1062
# Val Reconstruction Loss: 0.0483
# Epoch [386/500], Loss: 0.0464
# Epoch [386/500], Reconstruction Loss: 0.0270
# Val Loss: 0.1061
# Val Reconstruction Loss: 0.0483
# Epoch [387/500], Loss: 0.0474
# Epoch [387/500], Reconstruction Loss: 0.0279
# Val Loss: 0.1060
# Val Reconstruction Loss: 0.0483
# Epoch [388/500], Loss: 0.0569
# Epoch [388/500], Reconstruction Loss: 0.0332
# Val Loss: 0.1059
# Val Reconstruction Loss: 0.0483
# Epoch [389/500], Loss: 0.0481
# Epoch [389/500], Reconstruction Loss: 0.0277
# Val Loss: 0.1058
# Val Reconstruction Loss: 0.0483
# Epoch [390/500], Loss: 0.0505
# Epoch [390/500], Reconstruction Loss: 0.0295
# Val Loss: 0.1057
# Val Reconstruction Loss: 0.0483
# Epoch [391/500], Loss: 0.0589
# Epoch [391/500], Reconstruction Loss: 0.0341
# Val Loss: 0.1056
# Val Reconstruction Loss: 0.0483
# Epoch [392/500], Loss: 0.0459
# Epoch [392/500], Reconstruction Loss: 0.0270
# Val Loss: 0.1056
# Val Reconstruction Loss: 0.0484
# Epoch [393/500], Loss: 0.0565
# Epoch [393/500], Reconstruction Loss: 0.0331
# Val Loss: 0.1055
# Val Reconstruction Loss: 0.0484
# Epoch [394/500], Loss: 0.0506
# Epoch [394/500], Reconstruction Loss: 0.0290
# Val Loss: 0.1054
# Val Reconstruction Loss: 0.0484
# Epoch [395/500], Loss: 0.0482
# Epoch [395/500], Reconstruction Loss: 0.0287
# Val Loss: 0.1053
# Val Reconstruction Loss: 0.0484
# Epoch [396/500], Loss: 0.0498
# Epoch [396/500], Reconstruction Loss: 0.0296
# Val Loss: 0.1052
# Val Reconstruction Loss: 0.0484
# Epoch [397/500], Loss: 0.0565
# Epoch [397/500], Reconstruction Loss: 0.0319
# Val Loss: 0.1050
# Val Reconstruction Loss: 0.0484
# Epoch [398/500], Loss: 0.0595
# Epoch [398/500], Reconstruction Loss: 0.0358
# Val Loss: 0.1049
# Val Reconstruction Loss: 0.0484
# Epoch [399/500], Loss: 0.0477
# Epoch [399/500], Reconstruction Loss: 0.0287
# Val Loss: 0.1048
# Val Reconstruction Loss: 0.0484
# Epoch [400/500], Loss: 0.0518
# Epoch [400/500], Reconstruction Loss: 0.0310
# Val Loss: 0.1047
# Val Reconstruction Loss: 0.0484
# Epoch [401/500], Loss: 0.0468
# Epoch [401/500], Reconstruction Loss: 0.0281
# Val Loss: 0.1046
# Val Reconstruction Loss: 0.0484
# Epoch [402/500], Loss: 0.0492
# Epoch [402/500], Reconstruction Loss: 0.0293
# Val Loss: 0.1045
# Val Reconstruction Loss: 0.0484
# Epoch [403/500], Loss: 0.0483
# Epoch [403/500], Reconstruction Loss: 0.0281
# Val Loss: 0.1043
# Val Reconstruction Loss: 0.0484
# Epoch [404/500], Loss: 0.0470
# Epoch [404/500], Reconstruction Loss: 0.0281
# Val Loss: 0.1042
# Val Reconstruction Loss: 0.0484
# Epoch [405/500], Loss: 0.0458
# Epoch [405/500], Reconstruction Loss: 0.0275
# Val Loss: 0.1041
# Val Reconstruction Loss: 0.0484
# Epoch [406/500], Loss: 0.0606
# Epoch [406/500], Reconstruction Loss: 0.0348
# Val Loss: 0.1039
# Val Reconstruction Loss: 0.0484
# Epoch [407/500], Loss: 0.0464
# Epoch [407/500], Reconstruction Loss: 0.0281
# Val Loss: 0.1038
# Val Reconstruction Loss: 0.0484
# Epoch [408/500], Loss: 0.0545
# Epoch [408/500], Reconstruction Loss: 0.0339
# Val Loss: 0.1037
# Val Reconstruction Loss: 0.0484
# Epoch [409/500], Loss: 0.0456
# Epoch [409/500], Reconstruction Loss: 0.0272
# Val Loss: 0.1036
# Val Reconstruction Loss: 0.0484
# Epoch [410/500], Loss: 0.0450
# Epoch [410/500], Reconstruction Loss: 0.0273
# Val Loss: 0.1035
# Val Reconstruction Loss: 0.0485
# Epoch [411/500], Loss: 0.0560
# Epoch [411/500], Reconstruction Loss: 0.0341
# Val Loss: 0.1034
# Val Reconstruction Loss: 0.0485
# Epoch [412/500], Loss: 0.0544
# Epoch [412/500], Reconstruction Loss: 0.0310
# Val Loss: 0.1032
# Val Reconstruction Loss: 0.0485
# Epoch [413/500], Loss: 0.0495
# Epoch [413/500], Reconstruction Loss: 0.0298
# Val Loss: 0.1031
# Val Reconstruction Loss: 0.0485
# Epoch [414/500], Loss: 0.0570
# Epoch [414/500], Reconstruction Loss: 0.0341
# Val Loss: 0.1029
# Val Reconstruction Loss: 0.0485
# Epoch [415/500], Loss: 0.0575
# Epoch [415/500], Reconstruction Loss: 0.0330
# Val Loss: 0.1028
# Val Reconstruction Loss: 0.0485
# Epoch [416/500], Loss: 0.0593
# Epoch [416/500], Reconstruction Loss: 0.0356
# Val Loss: 0.1027
# Val Reconstruction Loss: 0.0485
# Epoch [417/500], Loss: 0.0474
# Epoch [417/500], Reconstruction Loss: 0.0285
# Val Loss: 0.1026
# Val Reconstruction Loss: 0.0485
# Epoch [418/500], Loss: 0.0517
# Epoch [418/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1025
# Val Reconstruction Loss: 0.0485
# Epoch [419/500], Loss: 0.0506
# Epoch [419/500], Reconstruction Loss: 0.0303
# Val Loss: 0.1023
# Val Reconstruction Loss: 0.0485
# Epoch [420/500], Loss: 0.0476
# Epoch [420/500], Reconstruction Loss: 0.0287
# Val Loss: 0.1022
# Val Reconstruction Loss: 0.0485
# Epoch [421/500], Loss: 0.0505
# Epoch [421/500], Reconstruction Loss: 0.0305
# Val Loss: 0.1020
# Val Reconstruction Loss: 0.0485
# Epoch [422/500], Loss: 0.0458
# Epoch [422/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1019
# Val Reconstruction Loss: 0.0485
# Epoch [423/500], Loss: 0.0457
# Epoch [423/500], Reconstruction Loss: 0.0282
# Val Loss: 0.1018
# Val Reconstruction Loss: 0.0485
# Epoch [424/500], Loss: 0.0567
# Epoch [424/500], Reconstruction Loss: 0.0338
# Val Loss: 0.1017
# Val Reconstruction Loss: 0.0485
# Epoch [425/500], Loss: 0.0493
# Epoch [425/500], Reconstruction Loss: 0.0307
# Val Loss: 0.1016
# Val Reconstruction Loss: 0.0485
# Epoch [426/500], Loss: 0.0522
# Epoch [426/500], Reconstruction Loss: 0.0320
# Val Loss: 0.1015
# Val Reconstruction Loss: 0.0485
# Epoch [427/500], Loss: 0.0515
# Epoch [427/500], Reconstruction Loss: 0.0316
# Val Loss: 0.1013
# Val Reconstruction Loss: 0.0485
# Epoch [428/500], Loss: 0.0462
# Epoch [428/500], Reconstruction Loss: 0.0284
# Val Loss: 0.1012
# Val Reconstruction Loss: 0.0485
# Epoch [429/500], Loss: 0.0490
# Epoch [429/500], Reconstruction Loss: 0.0295
# Val Loss: 0.1011
# Val Reconstruction Loss: 0.0485
# Epoch [430/500], Loss: 0.0571
# Epoch [430/500], Reconstruction Loss: 0.0373
# Val Loss: 0.1010
# Val Reconstruction Loss: 0.0485
# Epoch [431/500], Loss: 0.0552
# Epoch [431/500], Reconstruction Loss: 0.0324
# Val Loss: 0.1009
# Val Reconstruction Loss: 0.0485
# Epoch [432/500], Loss: 0.0549
# Epoch [432/500], Reconstruction Loss: 0.0326
# Val Loss: 0.1009
# Val Reconstruction Loss: 0.0485
# Epoch [433/500], Loss: 0.0471
# Epoch [433/500], Reconstruction Loss: 0.0296
# Val Loss: 0.1007
# Val Reconstruction Loss: 0.0486
# Epoch [434/500], Loss: 0.0476
# Epoch [434/500], Reconstruction Loss: 0.0292
# Val Loss: 0.1006
# Val Reconstruction Loss: 0.0486
# Epoch [435/500], Loss: 0.0532
# Epoch [435/500], Reconstruction Loss: 0.0314
# Val Loss: 0.1005
# Val Reconstruction Loss: 0.0486
# Epoch [436/500], Loss: 0.0495
# Epoch [436/500], Reconstruction Loss: 0.0306
# Val Loss: 0.1004
# Val Reconstruction Loss: 0.0486
# Epoch [437/500], Loss: 0.0466
# Epoch [437/500], Reconstruction Loss: 0.0295
# Val Loss: 0.1003
# Val Reconstruction Loss: 0.0486
# Epoch [438/500], Loss: 0.0487
# Epoch [438/500], Reconstruction Loss: 0.0307
# Val Loss: 0.1002
# Val Reconstruction Loss: 0.0486
# Epoch [439/500], Loss: 0.0644
# Epoch [439/500], Reconstruction Loss: 0.0389
# Val Loss: 0.1001
# Val Reconstruction Loss: 0.0486
# Epoch [440/500], Loss: 0.0428
# Epoch [440/500], Reconstruction Loss: 0.0269
# Val Loss: 0.1000
# Val Reconstruction Loss: 0.0486
# Epoch [441/500], Loss: 0.0488
# Epoch [441/500], Reconstruction Loss: 0.0312
# Val Loss: 0.0999
# Val Reconstruction Loss: 0.0486
# Epoch [442/500], Loss: 0.0497
# Epoch [442/500], Reconstruction Loss: 0.0297
# Val Loss: 0.0998
# Val Reconstruction Loss: 0.0486
# Epoch [443/500], Loss: 0.0445
# Epoch [443/500], Reconstruction Loss: 0.0282
# Val Loss: 0.0997
# Val Reconstruction Loss: 0.0486
# Epoch [444/500], Loss: 0.0589
# Epoch [444/500], Reconstruction Loss: 0.0344
# Val Loss: 0.0995
# Val Reconstruction Loss: 0.0486
# Epoch [445/500], Loss: 0.0475
# Epoch [445/500], Reconstruction Loss: 0.0301
# Val Loss: 0.0994
# Val Reconstruction Loss: 0.0486
# Epoch [446/500], Loss: 0.0490
# Epoch [446/500], Reconstruction Loss: 0.0303
# Val Loss: 0.0993
# Val Reconstruction Loss: 0.0486
# Epoch [447/500], Loss: 0.0468
# Epoch [447/500], Reconstruction Loss: 0.0300
# Val Loss: 0.0992
# Val Reconstruction Loss: 0.0486
# Epoch [448/500], Loss: 0.0569
# Epoch [448/500], Reconstruction Loss: 0.0367
# Val Loss: 0.0991
# Val Reconstruction Loss: 0.0486
# Epoch [449/500], Loss: 0.0421
# Epoch [449/500], Reconstruction Loss: 0.0270
# Val Loss: 0.0990
# Val Reconstruction Loss: 0.0486
# Epoch [450/500], Loss: 0.0446
# Epoch [450/500], Reconstruction Loss: 0.0281
# Val Loss: 0.0989
# Val Reconstruction Loss: 0.0486
# Epoch [451/500], Loss: 0.0464
# Epoch [451/500], Reconstruction Loss: 0.0288
# Val Loss: 0.0989
# Val Reconstruction Loss: 0.0486
# Epoch [452/500], Loss: 0.0467
# Epoch [452/500], Reconstruction Loss: 0.0297
# Val Loss: 0.0988
# Val Reconstruction Loss: 0.0487
# Epoch [453/500], Loss: 0.0494
# Epoch [453/500], Reconstruction Loss: 0.0302
# Val Loss: 0.0987
# Val Reconstruction Loss: 0.0487
# Epoch [454/500], Loss: 0.0537
# Epoch [454/500], Reconstruction Loss: 0.0344
# Val Loss: 0.0985
# Val Reconstruction Loss: 0.0487
# Epoch [455/500], Loss: 0.0507
# Epoch [455/500], Reconstruction Loss: 0.0317
# Val Loss: 0.0984
# Val Reconstruction Loss: 0.0487
# Epoch [456/500], Loss: 0.0453
# Epoch [456/500], Reconstruction Loss: 0.0284
# Val Loss: 0.0982
# Val Reconstruction Loss: 0.0487
# Epoch [457/500], Loss: 0.0500
# Epoch [457/500], Reconstruction Loss: 0.0317
# Val Loss: 0.0981
# Val Reconstruction Loss: 0.0487
# Epoch [458/500], Loss: 0.0575
# Epoch [458/500], Reconstruction Loss: 0.0353
# Val Loss: 0.0980
# Val Reconstruction Loss: 0.0487
# Epoch [459/500], Loss: 0.0502
# Epoch [459/500], Reconstruction Loss: 0.0310
# Val Loss: 0.0979
# Val Reconstruction Loss: 0.0487
# Epoch [460/500], Loss: 0.0548
# Epoch [460/500], Reconstruction Loss: 0.0365
# Val Loss: 0.0977
# Val Reconstruction Loss: 0.0487
# Epoch [461/500], Loss: 0.0434
# Epoch [461/500], Reconstruction Loss: 0.0280
# Val Loss: 0.0976
# Val Reconstruction Loss: 0.0487
# Epoch [462/500], Loss: 0.0531
# Epoch [462/500], Reconstruction Loss: 0.0327
# Val Loss: 0.0975
# Val Reconstruction Loss: 0.0487
# Epoch [463/500], Loss: 0.0587
# Epoch [463/500], Reconstruction Loss: 0.0392
# Val Loss: 0.0974
# Val Reconstruction Loss: 0.0487
# Epoch [464/500], Loss: 0.0456
# Epoch [464/500], Reconstruction Loss: 0.0298
# Val Loss: 0.0973
# Val Reconstruction Loss: 0.0487
# Epoch [465/500], Loss: 0.0466
# Epoch [465/500], Reconstruction Loss: 0.0301
# Val Loss: 0.0972
# Val Reconstruction Loss: 0.0487
# Epoch [466/500], Loss: 0.0417
# Epoch [466/500], Reconstruction Loss: 0.0268
# Val Loss: 0.0971
# Val Reconstruction Loss: 0.0487
# Epoch [467/500], Loss: 0.0432
# Epoch [467/500], Reconstruction Loss: 0.0282
# Val Loss: 0.0970
# Val Reconstruction Loss: 0.0487
# Epoch [468/500], Loss: 0.0438
# Epoch [468/500], Reconstruction Loss: 0.0288
# Val Loss: 0.0969
# Val Reconstruction Loss: 0.0487
# Epoch [469/500], Loss: 0.0441
# Epoch [469/500], Reconstruction Loss: 0.0288
# Val Loss: 0.0968
# Val Reconstruction Loss: 0.0487
# Epoch [470/500], Loss: 0.0523
# Epoch [470/500], Reconstruction Loss: 0.0342
# Val Loss: 0.0967
# Val Reconstruction Loss: 0.0487
# Epoch [471/500], Loss: 0.0428
# Epoch [471/500], Reconstruction Loss: 0.0284
# Val Loss: 0.0966
# Val Reconstruction Loss: 0.0487
# Epoch [472/500], Loss: 0.0422
# Epoch [472/500], Reconstruction Loss: 0.0276
# Val Loss: 0.0965
# Val Reconstruction Loss: 0.0487
# Epoch [473/500], Loss: 0.0572
# Epoch [473/500], Reconstruction Loss: 0.0353
# Val Loss: 0.0965
# Val Reconstruction Loss: 0.0487
# Epoch [474/500], Loss: 0.0427
# Epoch [474/500], Reconstruction Loss: 0.0283
# Val Loss: 0.0964
# Val Reconstruction Loss: 0.0488
# Epoch [475/500], Loss: 0.0459
# Epoch [475/500], Reconstruction Loss: 0.0304
# Val Loss: 0.0963
# Val Reconstruction Loss: 0.0488
# Epoch [476/500], Loss: 0.0481
# Epoch [476/500], Reconstruction Loss: 0.0320
# Val Loss: 0.0963
# Val Reconstruction Loss: 0.0488
# Epoch [477/500], Loss: 0.0490
# Epoch [477/500], Reconstruction Loss: 0.0327
# Val Loss: 0.0962
# Val Reconstruction Loss: 0.0488
# Epoch [478/500], Loss: 0.0421
# Epoch [478/500], Reconstruction Loss: 0.0281
# Val Loss: 0.0961
# Val Reconstruction Loss: 0.0488
# Epoch [479/500], Loss: 0.0477
# Epoch [479/500], Reconstruction Loss: 0.0321
# Val Loss: 0.0961
# Val Reconstruction Loss: 0.0488
# Epoch [480/500], Loss: 0.0534
# Epoch [480/500], Reconstruction Loss: 0.0333
# Val Loss: 0.0960
# Val Reconstruction Loss: 0.0488
# Epoch [481/500], Loss: 0.0425
# Epoch [481/500], Reconstruction Loss: 0.0284
# Val Loss: 0.0959
# Val Reconstruction Loss: 0.0488
# Epoch [482/500], Loss: 0.0457
# Epoch [482/500], Reconstruction Loss: 0.0308
# Val Loss: 0.0958
# Val Reconstruction Loss: 0.0488
# Epoch [483/500], Loss: 0.0408
# Epoch [483/500], Reconstruction Loss: 0.0276
# Val Loss: 0.0957
# Val Reconstruction Loss: 0.0488
# Epoch [484/500], Loss: 0.0536
# Epoch [484/500], Reconstruction Loss: 0.0351
# Val Loss: 0.0956
# Val Reconstruction Loss: 0.0488
# Epoch [485/500], Loss: 0.0533
# Epoch [485/500], Reconstruction Loss: 0.0336
# Val Loss: 0.0955
# Val Reconstruction Loss: 0.0488
# Epoch [486/500], Loss: 0.0510
# Epoch [486/500], Reconstruction Loss: 0.0342
# Val Loss: 0.0954
# Val Reconstruction Loss: 0.0488
# Epoch [487/500], Loss: 0.0474
# Epoch [487/500], Reconstruction Loss: 0.0306
# Val Loss: 0.0953
# Val Reconstruction Loss: 0.0488
# Epoch [488/500], Loss: 0.0482
# Epoch [488/500], Reconstruction Loss: 0.0319
# Val Loss: 0.0952
# Val Reconstruction Loss: 0.0488
# Epoch [489/500], Loss: 0.0435
# Epoch [489/500], Reconstruction Loss: 0.0292
# Val Loss: 0.0951
# Val Reconstruction Loss: 0.0488
# Epoch [490/500], Loss: 0.0464
# Epoch [490/500], Reconstruction Loss: 0.0314
# Val Loss: 0.0950
# Val Reconstruction Loss: 0.0488
# Epoch [491/500], Loss: 0.0421
# Epoch [491/500], Reconstruction Loss: 0.0282
# Val Loss: 0.0949
# Val Reconstruction Loss: 0.0488
# Epoch [492/500], Loss: 0.0398
# Epoch [492/500], Reconstruction Loss: 0.0268
# Val Loss: 0.0948
# Val Reconstruction Loss: 0.0488
# Epoch [493/500], Loss: 0.0439
# Epoch [493/500], Reconstruction Loss: 0.0289
# Val Loss: 0.0947
# Val Reconstruction Loss: 0.0488
# Epoch [494/500], Loss: 0.0504
# Epoch [494/500], Reconstruction Loss: 0.0337
# Val Loss: 0.0946
# Val Reconstruction Loss: 0.0489
# Epoch [495/500], Loss: 0.0418
# Epoch [495/500], Reconstruction Loss: 0.0285
# Val Loss: 0.0946
# Val Reconstruction Loss: 0.0489
# Epoch [496/500], Loss: 0.0576
# Epoch [496/500], Reconstruction Loss: 0.0363
# Val Loss: 0.0945
# Val Reconstruction Loss: 0.0489
# Epoch [497/500], Loss: 0.0577
# Epoch [497/500], Reconstruction Loss: 0.0374
# Val Loss: 0.0944
# Val Reconstruction Loss: 0.0489
# Epoch [498/500], Loss: 0.0429
# Epoch [498/500], Reconstruction Loss: 0.0288
# Val Loss: 0.0943
# Val Reconstruction Loss: 0.0489
# Epoch [499/500], Loss: 0.0498
# Epoch [499/500], Reconstruction Loss: 0.0338
# Val Loss: 0.0943
# Val Reconstruction Loss: 0.0489
# Epoch [500/500], Loss: 0.0400
# Epoch [500/500], Reconstruction Loss: 0.0274
# Val Loss: 0.0942
# Val Reconstruction Loss: 0.0489

# %%
# Plotting the losses
plt.figure(figsize=(12, 6))

# Plot total loss
plt.plot(train_losses, label="Train Total Loss")
plt.plot(val_losses, label="Val Total Loss")
plt.xlabel("Epoch")
plt.ylabel("Total Loss")
plt.title("Training and Validation Total Loss")
plt.legend()
plt.show()

# # Plot reconstruction loss
# plt.figure(figsize=(12, 6))
# plt.plot(train_reconstruction_losses, label="Train Reconstruction Loss")
# plt.plot(val_reconstruction_losses, label="Val Reconstruction Loss")
# plt.xlabel("Epoch")
# plt.ylabel("Reconstruction Loss")
# plt.title("Training and Validation Reconstruction Loss")
# plt.legend()
# plt.show()

# %% [markdown]
# ### Extracting Low-Dimensional Representation for Regression

# %%
model.eval()
with torch.no_grad():
    _, X_train_encoded = model(X_train_tensor)
    _, X_val_encoded = model(X_val_tensor)
    
X_train_encoded_np = X_train_encoded.numpy()
X_val_encoded_np = X_val_encoded.numpy()
y_train_np = y_train_tensor.numpy().ravel()
y_val_np=y_val_tensor.numpy().ravel()
# # Split encoded train data into training and validation sets for regression
# X_train_reg, X_val_reg = X_train_encoded_np[:train_size], X_train_encoded_np[train_size:]
# y_train_reg, y_val_reg = y_train_np[:train_size], y_train_np[train_size:]

# %% [markdown]
# ### Training the Random Forest Regressor

# %%
# Initialize and train RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=500, random_state=42)
regressor.fit(X_train_encoded_np, y_train_np)

# Make predictions on validation set
y_pred_val = regressor.predict(X_val_encoded_np)
val_rmse = mean_squared_error(y_val_np, y_pred_val, squared=False)
print(f"Validation RMSE: {val_rmse:.4f}")

# Predict on test set if needed
y_pred_val = regressor.predict(X_val_encoded_np)
# Out:
# Validation RMSE: 4.1694

# %% [markdown]
# ###  Plot Predicted vs Actual (for Validation Set)

# %%
plt.scatter(y_val_np, y_pred_val, alpha=0.7)
plt.xlabel("Actual IgG_PT (Validation)")
plt.ylabel("Predicted IgG_PT (Validation)")
plt.title("Validation Set: Predicted vs Actual IgG_PT")
plt.plot([y_val_np.min(), y_val_np.max()], [y_val_np.min(), y_val_np.max()], 'k--')
plt.show()
np.corrcoef(y_val_np, y_pred_val)
# Out:
# array([[1.        , 0.69975003],
#        [0.69975003, 1.        ]])

# %%
from scipy.stats import spearmanr

# Assuming y_true and y_pred are your true and predicted values as 1D arrays
# Replace these with your actual values
y_true = y_val_np  # e.g., y_train or y_test
y_pred = y_pred_val # e.g., model.predict(X_test)

# Calculate Spearman's rank correlation
spearman_corr, _ = spearmanr(y_true, y_pred)

print(f"Spearman's Rank Correlation Coefficient: {spearman_corr:.4f}")
# Out:
# Spearman's Rank Correlation Coefficient: 0.6364

# %%
# Assuming `y_true` and `y_pred` are numpy arrays or similar
def calculate_normalized_error_norm(y_true, y_pred):
    # Calculate the numerator: ||y_true - y_pred||
    error_norm = np.linalg.norm(y_true - y_pred)
    # Calculate the denominator: ||y_true||
    true_norm = np.linalg.norm(y_true)
    # Calculate the normalized error norm
    normalized_error_norm = error_norm / true_norm
    return normalized_error_norm

y_true = y_val_np  # e.g., y_train or y_test
y_pred = y_pred_val # e.g., model.predict(X_test)

normalized_error = calculate_normalized_error_norm(y_true, y_pred)  # Replace with actual data
print(f"Normalized Error Norm: {normalized_error:.4f}")
# Out:
# Normalized Error Norm: 0.4563

# %% [markdown]
# ### Retraining on the whole training set and generating predictions for test.

# %%
# Convert the split data into tensors
X_train_final_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_train_final_tensor = torch.tensor(y_train.to_numpy(), dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.to_numpy(), dtype=torch.float32)

# Set up DataLoaders
batch_size = 32
train_final_dataset = TensorDataset(X_train_final_tensor, y_train_final_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_final_loader = DataLoader(train_final_dataset, batch_size=batch_size, shuffle=True)
x=next(iter(train_final_loader))
# print(x[1].shape)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
